# %%
import tensorflow as tf
from tensorflow.keras.metrics import *
from tensorflow.keras.layers import *
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.applications import *
from tensorflow.keras.optimizers import Adam, Nadam
from tensorflow.keras.callbacks import *
from tensorflow.keras import backend as K
from hausdorff import hausdorff_distance
#import lr_scheduler
from tensorflow.keras.regularizers import l2

import os
import random
import numpy as np
from tqdm import tqdm
from skimage.io import imread,imshow
from skimage.morphology import label
from skimage.transform import resize
import matplotlib.pyplot as plt
import datetime


from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Conv2D, concatenate
import sys
sys.path.append('../')
from keras_vision_transformer import swin_layers
from keras_vision_transformer import transformer_layers
from keras_vision_transformer import utils

# %%
TRAIN_PATH="DRIVE/training/"
TEST_PATH="DRIVE/test/"

# %%
train_ids=next(os.walk(TRAIN_PATH+'images/'))[2][:]
test_ids=next(os.walk(TEST_PATH+'images/'))[2][:]
print(len(train_ids))
# Out:
# 20

# %%
input_height = IMG_HEIGHT = 256
input_width = IMG_WIDTH = 256
IMG_CHANNELS = 3

# %%
X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.float32)
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.float32)
X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.float32)
Y_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.float32)

print('Resizing training images and masks')
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):   
    path = TRAIN_PATH + 'images/' + id_
    img = imread(path)[:,:,:IMG_CHANNELS]  
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_train[n] = img #/ 255. #Fill empty X_train with values from img
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
    mask_path = TRAIN_PATH + 'mask/' + id_[:-4] + '_mask.gif'
    mask = imread(mask_path)
    mask = np.expand_dims(mask, axis=-1)
    mask = resize(mask, (input_width, input_height), mode='constant', preserve_range=True)
    mask = mask/255
    Y_train[n][mask > 0.] = 1.

print('Resizing test images and masks')
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):   
    path = TEST_PATH + 'images/' + id_
    img = imread(path)[:,:,:IMG_CHANNELS]  
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_test[n] = img #/ 255. #Fill empty X_train with values from img
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
    mask_path = TEST_PATH + 'mask/' + id_[:-4] + '_mask.gif'
    mask = imread(mask_path)
    mask = np.expand_dims(mask, axis=-1)
    mask = resize(mask, (input_width, input_height), mode='constant', preserve_range=True)
    mask = mask/255
    Y_test[n][mask > 0.] = 1.
# Out:
# Resizing training images and masks
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]C:\Users\manda\AppData\Local\Temp\ipykernel_16636\727015007.py:12: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [00:03<00:00,  5.20it/s]
# Resizing test images and masks
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]C:\Users\manda\AppData\Local\Temp\ipykernel_16636\727015007.py:26: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [00:03<00:00,  5.88it/s]

# %%
print(X_train.shape, Y_test.shape)
# Out:
# (20, 256, 256, 3) (20, 256, 256, 1)

# %%
ix=0
imshow(X_train[ix].astype('int'))
plt.show()
imshow(np.squeeze(Y_train[ix].astype('int')))
plt.show()
# Out:
# C:\Users\manda\anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:150: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
plt.figure(figsize=(30,30))
x, y = 5, 4
count=1
for i in range(y):
    for j in range(x):
        plt.subplot(y*2, x, i*2*x+j+1)
        pos = i+j
        plt.imshow(X_train[pos].astype('int'))
        plt.title('Image {}'.format(count))
        plt.axis('off')
        plt.subplot(y*2, x, (i*2+1)*x+j+1)
        plt.imshow(np.squeeze(Y_train[pos].astype('int')))
        plt.title('Mask {}'.format(count))
        plt.axis('off')
        count = count + 1
plt.show()

# %%
def expend_as(tensor, rep):
     return Lambda(lambda x, repnum: K.repeat_elements(x, repnum, axis=3),
                          arguments={'repnum': rep})(tensor)

def double_conv_layer(x, filter_size, size, dropout, batch_norm=False):
    axis = 3
    conv = SeparableConv2D(size, (filter_size, filter_size), padding='same')(x)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    conv = SeparableConv2D(size, (filter_size, filter_size), padding='same')(conv)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    if dropout > 0:
        conv = Dropout(dropout)(conv)

    shortcut = Conv2D(size, kernel_size=(1, 1), padding='same')(x)
    if batch_norm is True:
        shortcut = BatchNormalization(axis=axis)(shortcut)

    res_path = add([shortcut, conv])
    return res_path

def encoder(inputs):
    num_filters = [16, 32, 64, 128]
    skip_connections = []
    x = inputs

    for i, f in enumerate(num_filters):
        a = double_conv_layer(x, 3, f, 0.1, True)
        skip_connections.append(a)
        x = MaxPooling2D(pool_size=(2, 2))(a)
    
    return x, skip_connections

def bottleneck(inputs):
    x = inputs
    f = 256
    
    x3 = double_conv_layer(x, 3, f, 0.1, True)
    
    return x3

def decoder(inputs, skip_connections):
    num_filters = [128, 64, 32, 16]
    skip_connections.reverse()
    x = inputs
    batch_norm = True
    
    for i, f in enumerate(num_filters):
        
        x_up = UpSampling2D(size=(2, 2), data_format="channels_last")(x)
        x_att = concatenate([x_up, skip_connections[i]], axis=-1)
        
        x = double_conv_layer(x_att, 3, f, 0.1, True)
    return x

def output(inputs):
    x = Conv2D(1, kernel_size=(1,1))(inputs)
    x = BatchNormalization()(x)
    x = Activation('sigmoid')(x)
    
    return x

# %%
def swin_transformer_stack(X, stack_num, embed_dim, num_patch, num_heads, window_size, num_mlp, shift_window=True, name=''):
    '''
    Stacked Swin Transformers that share the same token size.
    
    Alternated Window-MSA and Swin-MSA will be configured if `shift_window=True`, Window-MSA only otherwise.
    *Dropout is turned off.
    '''
    # Turn-off dropouts
    mlp_drop_rate = 0 # Droupout after each MLP layer
    attn_drop_rate = 0 # Dropout after Swin-Attention
    proj_drop_rate = 0 # Dropout at the end of each Swin-Attention block, i.e., after linear projections
    drop_path_rate = 0 # Drop-path within skip-connections
    
    qkv_bias = True # Convert embedded patches to query, key, and values with a learnable additive value
    qk_scale = None # None: Re-scale query based on embed dimensions per attention head # Float for user specified scaling factor
    
    if shift_window:
        shift_size = window_size // 2
    else:
        shift_size = 0
    
    for i in range(stack_num):
    
        if i % 2 == 0:
            shift_size_temp = 0
        else:
            shift_size_temp = shift_size

        X = swin_layers.SwinTransformerBlock(dim=embed_dim, 
                                             num_patch=num_patch, 
                                             num_heads=num_heads, 
                                             window_size=window_size, 
                                             shift_size=shift_size_temp, 
                                             num_mlp=num_mlp, 
                                             qkv_bias=qkv_bias, 
                                             qk_scale=qk_scale,
                                             mlp_drop=mlp_drop_rate, 
                                             attn_drop=attn_drop_rate, 
                                             proj_drop=proj_drop_rate, 
                                             drop_path_prob=drop_path_rate, 
                                             name='name{}'.format(i))(X)
    return X

# %%
def swin_unet_2d_base(input_tensor, filter_num_begin, depth, stack_num_down, stack_num_up, 
                      patch_size, num_heads, window_size, num_mlp, shift_window=True, name='swin_unet'):
    '''
    The base of Swin-UNET.
    
    The general structure:
    
    1. Input image --> a sequence of patches --> tokenize these patches
    2. Downsampling: swin-transformer --> patch merging (pooling)
    3. Upsampling: concatenate --> swin-transfprmer --> patch expanding (unpooling)
    4. Model head
    
    '''
    # Compute number be patches to be embeded
    input_size = input_tensor.shape.as_list()[1:]
    num_patch_x = input_size[0]//patch_size[0]
    num_patch_y = input_size[1]//patch_size[1]
    
    # Number of Embedded dimensions
    embed_dim = filter_num_begin
    
    depth_ = depth
    
    X_skip = []

    X = input_tensor
    
    # Patch extraction
    X = transformer_layers.patch_extract(patch_size)(X)

    # Embed patches to tokens
    X = transformer_layers.patch_embedding(num_patch_x*num_patch_y, embed_dim)(X)
    
    # The first Swin Transformer stack
    X = swin_transformer_stack(X, 
                               stack_num=stack_num_down, 
                               embed_dim=embed_dim, 
                               num_patch=(num_patch_x, num_patch_y), 
                               num_heads=num_heads[0], 
                               window_size=window_size[0], 
                               num_mlp=num_mlp, 
                               shift_window=shift_window, 
                               name='{}_swin_down0'.format(name))
    X_skip.append(X)
    
    # Downsampling blocks
    for i in range(depth_-1):
        
        # Patch merging
        X = transformer_layers.patch_merging((num_patch_x, num_patch_y), embed_dim=embed_dim, name='down{}'.format(i))(X)
        
        # update token shape info
        embed_dim = embed_dim*2
        num_patch_x = num_patch_x//2
        num_patch_y = num_patch_y//2
        
        # Swin Transformer stacks
        X = swin_transformer_stack(X, 
                                   stack_num=stack_num_down, 
                                   embed_dim=embed_dim, 
                                   num_patch=(num_patch_x, num_patch_y), 
                                   num_heads=num_heads[i+1], 
                                   window_size=window_size[i+1], 
                                   num_mlp=num_mlp, 
                                   shift_window=shift_window, 
                                   name='{}_swin_down{}'.format(name, i+1))
        
        # Store tensors for concat
        X_skip.append(X)
        
    # reverse indexing encoded tensors and hyperparams
    X_skip = X_skip[::-1]
    num_heads = num_heads[::-1]
    window_size = window_size[::-1]
    
    # upsampling begins at the deepest available tensor
    X = X_skip[0]
    
    # other tensors are preserved for concatenation
    X_decode = X_skip[1:]
    
    depth_decode = len(X_decode)
    
    for i in range(depth_decode):
        
        # Patch expanding
        X = transformer_layers.patch_expanding(num_patch=(num_patch_x, num_patch_y), 
                                               embed_dim=embed_dim, 
                                               upsample_rate=2, 
                                               return_vector=True)(X)
        

        # update token shape info
        embed_dim = embed_dim//2
        num_patch_x = num_patch_x*2
        num_patch_y = num_patch_y*2
        
        # Concatenation and linear projection
        X = concatenate([X, X_decode[i]], axis=-1, name='{}_concat_{}'.format(name, i))
        X = Dense(embed_dim, use_bias=False, name='{}_concat_linear_proj_{}'.format(name, i))(X)
        
        # Swin Transformer stacks
        X = swin_transformer_stack(X, 
                                   stack_num=stack_num_up, 
                                   embed_dim=embed_dim, 
                                   num_patch=(num_patch_x, num_patch_y), 
                                   num_heads=num_heads[i], 
                                   window_size=window_size[i], 
                                   num_mlp=num_mlp, 
                                   shift_window=shift_window, 
                                   name='{}_swin_up{}'.format(name, i))
        
    # The last expanding layer; it produces full-size feature maps based on the patch size
    # !!! <--- "patch_size[0]" is used; it assumes patch_size = (size, size)
    
    X = transformer_layers.patch_expanding(num_patch=(num_patch_x, num_patch_y), 
                                           embed_dim=embed_dim, 
                                           upsample_rate=patch_size[0], 
                                           return_vector=False)(X)
    
    return X

# %%
def encoder(input_tensor, filter_num_begin, depth, stack_num_down, stack_num_up, 
                      patch_size, num_heads, window_size, num_mlp, shift_window=True, name='swin_unet_encoder'):
    '''
    The base of Swin-UNET.
    
    The general structure:
    
    1. Input image --> a sequence of patches --> tokenize these patches
    2. Downsampling: swin-transformer --> patch merging (pooling)
    3. Upsampling: concatenate --> swin-transfprmer --> patch expanding (unpooling)
    4. Model head
    
    '''
    # Compute number be patches to be embeded
    input_size = input_tensor.shape.as_list()[1:]
    print("input_size",input_size)
    num_patch_x = input_size[0]//patch_size[0]
    print("num_patch_x",num_patch_x)
    num_patch_y = input_size[1]//patch_size[1]
    
    # Number of Embedded dimensions
    embed_dim = filter_num_begin
    
    depth_ = depth
    
    X_skip = []

    X = input_tensor
    
    # Patch extraction
    X = transformer_layers.patch_extract(patch_size)(X)

    # Embed patches to tokens
    X = transformer_layers.patch_embedding(num_patch_x*num_patch_y, embed_dim)(X)
    
    # The first Swin Transformer stack
    X = swin_transformer_stack(X, 
                               stack_num=stack_num_down, 
                               embed_dim=embed_dim, 
                               num_patch=(num_patch_x, num_patch_y), 
                               num_heads=num_heads[0], 
                               window_size=window_size[0], 
                               num_mlp=num_mlp, 
                               shift_window=shift_window, 
                               name='{}_swin_down0'.format(name))
    X_skip.append(X)
    
    # Downsampling blocks
    for i in range(depth_-1):
        
        # Patch merging
        X = transformer_layers.patch_merging((num_patch_x, num_patch_y), embed_dim=embed_dim, name='down{}'.format(i))(X)
        
        # update token shape info
        embed_dim = embed_dim*2
        num_patch_x = num_patch_x//2
        num_patch_y = num_patch_y//2
        
        # Swin Transformer stacks
        X = swin_transformer_stack(X, 
                                   stack_num=stack_num_down, 
                                   embed_dim=embed_dim, 
                                   num_patch=(num_patch_x, num_patch_y), 
                                   num_heads=num_heads[i+1], 
                                   window_size=window_size[i+1], 
                                   num_mlp=num_mlp, 
                                   shift_window=shift_window, 
                                   name='{}_swin_down{}'.format(name, i+1))
        
        # Store tensors for concat
        X_skip.append(X)
        
    
    
    return X, X_skip, embed_dim, num_patch_x, num_patch_y

def bottleneck(inputs):
    x = inputs
    f = 256
    
    x3 = double_conv_layer(x, 3, f, 0.1, True)
    
    return x3

def decoder(inputs, skip_connections):
    num_filters = [128, 64, 32, 16]
    skip_connections.reverse()
    x = inputs
    batch_norm = True
    
    for i, f in enumerate(num_filters):
        
        x_up = UpSampling2D(size=(2, 2), data_format="channels_last")(x)
        x_att = concatenate([x_up, skip_connections[i]], axis=-1)
        
        x = double_conv_layer(x_att, 3, f, 0.1, True)
    return x

def s_decoder(embed_dim,num_patch_x,num_patch_y, X_skip,filter_num_begin, depth, stack_num_down, stack_num_up, 
                      patch_size, num_heads, window_size, num_mlp, shift_window=True,name='swin_decoder'):
    #input_size = [256,256,3]
    #num_patch_x = input_size[0]//patch_size[0]
    #print("numPatchX",num_patch_x)
    #num_patch_y = input_size[1]//patch_size[1]
    #print("numPatchY",num_patch_y)
    # Number of Embedded dimensions
    #embed_dim = filter_num_begin
    
    depth_ = depth
    # reverse indexing encoded tensors and hyperparams
    X_skip = X_skip[::-1]
    num_heads = num_heads[::-1]
    window_size = window_size[::-1]
    
    
    
    # upsampling begins at the deepest available tensor
    X = X_skip[0]
    print("X_skip0",X)
    # other tensors are preserved for concatenation
    X_decode = X_skip[1:]
    print("X-decode", X_decode)
    
    depth_decode = len(X_decode)
    print("depth_decode nnnnnnnnnnnn",depth_decode)
    for i in range(depth_decode):
        
        # Patch expanding
        X = transformer_layers.patch_expanding(num_patch=(num_patch_x, num_patch_y), 
                                               embed_dim=embed_dim, 
                                               upsample_rate=2, 
                                               return_vector=True)(X)
        

        # update token shape info
        embed_dim = embed_dim//2
        num_patch_x = num_patch_x*2
        num_patch_y = num_patch_y*2
        
        # Concatenation and linear projection
        X = concatenate([X, X_decode[i]], axis=-1, name='{}_concat_{}'.format(name, i))
        X = Dense(embed_dim, use_bias=False, name='{}_concat_linear_proj_{}'.format(name, i))(X)
        
        # Swin Transformer stacks
        X = swin_transformer_stack(X, 
                                   stack_num=stack_num_up, 
                                   embed_dim=embed_dim, 
                                   num_patch=(num_patch_x, num_patch_y), 
                                   num_heads=num_heads[i], 
                                   window_size=window_size[i], 
                                   num_mlp=num_mlp, 
                                   shift_window=shift_window, 
                                   name='{}_swin_up{}'.format(name, i))
        
    # The last expanding layer; it produces full-size feature maps based on the patch size
    # !!! <--- "patch_size[0]" is used; it assumes patch_size = (size, size)
    
    X = transformer_layers.patch_expanding(num_patch=(num_patch_x, num_patch_y), 
                                           embed_dim=embed_dim, 
                                           upsample_rate=patch_size[0], 
                                           return_vector=False)(X)
    
    return X
    
    
    
    
    

def output(inputs):
    x = Conv2D(1, kernel_size=(1,1))(inputs)
    x = BatchNormalization()(x)
    x = Activation('sigmoid')(x)
    
    return x

# %%
filter_num_begin = 128     # number of channels in the first downsampling block; it is also the number of embedded dimensions
depth = 4               # the depth of SwinUNET; depth=4 means three down/upsampling levels and a bottom level 
stack_num_down = 2         # number of Swin Transformers per downsampling level
stack_num_up = 2           # number of Swin Transformers per upsampling level
patch_size = (4, 4)        # Extract 4-by-4 patches from the input image. Height and width of the patch must be equal.
num_heads = [4, 8, 8, 8]   # number of attention heads per down/upsampling level
window_size = [4, 2, 2, 2] # the size of attention window per down/upsampling level
num_mlp = 512              # number of MLP nodes within the Transformer
shift_window=True          # Apply window shifting, i.e., Swin-MSA

# %%
def random_resize_crop(image, scale=[0.75, 1.0], crop_size=128):
    if crop_size == 32:
        image_shape = 48
        image = tf.image.resize(image, (image_shape, image_shape))
    else:
        image_shape = 96
        image = tf.image.resize(image, (image_shape, image_shape))
    size = tf.random.uniform(
        shape=(1,),
        minval=scale[0] * image_shape,
        maxval=scale[1] * image_shape,
        dtype=tf.float32,
    )
    size = tf.cast(size, tf.int32)[0]
    crop = tf.image.random_crop(image, (size, size, 3))
    crop_resize = tf.image.resize(crop, (crop_size, crop_size))
    return crop_resize

def flip_random_crop(image):
    image = tf.image.random_flip_left_right(image)
    image = random_resize_crop(image, crop_size=CROP_TO)
    return image


@tf.function
def float_parameter(level, maxval):
    return tf.cast(level * maxval / 10.0, tf.float32)


@tf.function
def sample_level(n):
    return tf.random.uniform(shape=[1], minval=0.1, maxval=n, dtype=tf.float32)

def rotation(image):
    augmented_image = tf.image.rot90(image)
    return augmented_image

@tf.function
def solarize(image, level=6):
    threshold = float_parameter(sample_level(level), 1)
    return tf.where(image < threshold, image, 255 - image)

def color_jitter(x, strength=0.5):
    x = tf.image.random_brightness(x, max_delta=0.8 * strength)
    x = tf.image.random_contrast(
        x, lower=1 - 0.8 * strength, upper=1 + 0.8 * strength
    )
    x = tf.image.random_saturation(
        x, lower=1 - 0.8 * strength, upper=1 + 0.8 * strength
    )
    x = tf.image.random_hue(x, max_delta=0.2 * strength)
    x = tf.clip_by_value(x, 0, 255)
    return x


def color_drop(x):
    x = tf.image.rgb_to_grayscale(x)
    x = tf.tile(x, [1, 1, 3])
    return x


def random_apply(func, x, p):
    if tf.random.uniform([], minval=0, maxval=1) < p:
        return func(x)
    else:
        return x


def custom_augment(image):
    image = tf.cast(image, tf.float32)
    image = flip_random_crop(image)
    image = random_apply(rotation, image, p=0.5)
    #image = random_apply(color_jitter, image, p=0.9)
    #image = random_apply(color_drop, image, p=0.3)
    #image = random_apply(solarize, image, p=0.3)
    return image

# %%
AUTO = tf.data.AUTOTUNE
CROP_TO = IMG_HEIGHT
SEED = 42
BATCH_SIZE = 4
ssl_ds_one = tf.data.Dataset.from_tensor_slices(X_train)
ssl_ds_one = (
    ssl_ds_one.shuffle(1024, seed=SEED)
    .map(custom_augment, num_parallel_calls=AUTO)
    .batch(BATCH_SIZE)
    .prefetch(AUTO)
)

ssl_ds_two = tf.data.Dataset.from_tensor_slices(X_train)
ssl_ds_two = (
    ssl_ds_two.shuffle(1024, seed=SEED)
    .map(custom_augment, num_parallel_calls=AUTO)
    .batch(BATCH_SIZE)
    .prefetch(AUTO)
)

# We then zip both of these datasets.
ssl_ds = tf.data.Dataset.zip((ssl_ds_one, ssl_ds_two))

# %%
sample_images_one = next(iter(ssl_ds_one))
plt.figure(figsize=(10, 10))
for n in range(2):
    ax = plt.subplot(5, 5, n + 1)
    plt.imshow(sample_images_one[n].numpy().astype("int"))
    #print(sample_images_one[n].numpy().shape)
    plt.axis("off")
plt.show()

# %%
sample_images_two = next(iter(ssl_ds_two))
plt.figure(figsize=(10, 10))
for n in range(2):
    ax = plt.subplot(5, 5, n + 1)
    plt.imshow(sample_images_two[n].numpy().astype("int"))
    plt.axis("off")
plt.show()

# %%
def off_diagonal(x):
    n = tf.shape(x)[0]
    flattened = tf.reshape(x, [-1])[:-1]
    off_diagonals = tf.reshape(flattened, (n-1, n+1))[:, 1:]
    return tf.reshape(off_diagonals, [-1])


def normalize_repr(z):
    z_norm = (z - tf.reduce_mean(z, axis=0)) / tf.math.reduce_std(z, axis=0)
    return z_norm


def compute_loss(z_a, z_b, lambd):
    # Get batch size and representation dimension.
    batch_size = tf.cast(tf.shape(z_a)[0], z_a.dtype)
    repr_dim = tf.shape(z_a)[1]

    # Normalize the representations along the batch dimension.
    z_a_norm = normalize_repr(z_a)
    z_b_norm = normalize_repr(z_b)

    # Cross-correlation matrix.
    c = tf.matmul(z_a_norm, z_b_norm, transpose_a=True) / batch_size

    # Loss.
    on_diag = tf.linalg.diag_part(c) + (-1)
    on_diag = tf.reduce_sum(tf.pow(on_diag, 2))
    off_diag = off_diagonal(c)
    off_diag = tf.reduce_sum(tf.pow(off_diag, 2))
    loss = on_diag + (lambd * off_diag)
    return loss

# %%
class BarlowTwins(tf.keras.Model):
    def __init__(self, encoder, lambd=5e-3):
        super(BarlowTwins, self).__init__()
        self.encoder = encoder
        self.lambd = lambd
        self.loss_tracker = tf.keras.metrics.Mean(name="loss")

    @property
    def metrics(self):
        return [self.loss_tracker]

    def train_step(self, data):
        # Unpack the data.
        ds_one, ds_two = data

        # Forward pass through the encoder and predictor.
        with tf.GradientTape() as tape:
            z_a, z_b = self.encoder(ds_one, training=True), self.encoder(ds_two, training=True)
            loss = compute_loss(z_a, z_b, self.lambd) 

        # Compute gradients and update the parameters.
        gradients = tape.gradient(loss, self.encoder.trainable_variables)
        self.optimizer.apply_gradients(zip(gradients, self.encoder.trainable_variables))

        # Monitor loss.
        self.loss_tracker.update_state(loss)
        return {"loss": self.loss_tracker.result()}

# %%
class WarmUpCosine(tf.keras.optimizers.schedules.LearningRateSchedule):
    """
    Implements an LR scheduler that warms up the learning rate for some training steps
    (usually at the beginning of the training) and then decays it
    with CosineDecay (see https://arxiv.org/abs/1608.03983)
    """

    def __init__(
        self, learning_rate_base, total_steps, warmup_learning_rate, warmup_steps
    ):
        super(WarmUpCosine, self).__init__()

        self.learning_rate_base = learning_rate_base
        self.total_steps = total_steps
        self.warmup_learning_rate = warmup_learning_rate
        self.warmup_steps = warmup_steps
        self.pi = tf.constant(np.pi)

    def __call__(self, step):
        if self.total_steps < self.warmup_steps:
            raise ValueError("Total_steps must be larger or equal to warmup_steps.")
        learning_rate = (
            0.5
            * self.learning_rate_base
            * (
                1
                + tf.cos(
                    self.pi
                    * (tf.cast(step, tf.float32) - self.warmup_steps)
                    / float(self.total_steps - self.warmup_steps)
                )
            )
        )

        if self.warmup_steps > 0:
            if self.learning_rate_base < self.warmup_learning_rate:
                raise ValueError(
                    "Learning_rate_base must be larger or equal to "
                    "warmup_learning_rate."
                )
            slope = (
                self.learning_rate_base - self.warmup_learning_rate
            ) / self.warmup_steps
            warmup_rate = slope * tf.cast(step, tf.float32) + self.warmup_learning_rate
            learning_rate = tf.where(
                step < self.warmup_steps, warmup_rate, learning_rate
            )
        return tf.where(
            step > self.total_steps, 0.0, learning_rate, name="learning_rate"
        )

# %%
PROJECT_DIM = IMG_HEIGHT/2
BATCH_SIZE = 8
EPOCHS = 100
WEIGHT_DECAY = 5e-4
TRAIN_FLG = 1 # 0 - No Training, 1 - Training
val_split = 0.3

STEPS_PER_EPOCH = len(X_train) // BATCH_SIZE
TOTAL_STEPS = STEPS_PER_EPOCH * EPOCHS
WARMUP_EPOCHS = int(EPOCHS * 0.1)
WARMUP_STEPS = int(WARMUP_EPOCHS * STEPS_PER_EPOCH)

lr_decayed_fn = WarmUpCosine(
    learning_rate_base=1e-3,
    total_steps=EPOCHS * STEPS_PER_EPOCH,
    warmup_learning_rate=0.0,
    warmup_steps=WARMUP_STEPS
)

# %%
# Visualize the LR schedule
plt.plot(lr_decayed_fn(tf.range(EPOCHS*STEPS_PER_EPOCH, dtype=tf.float32)))
plt.ylabel("Learning Rate")
plt.xlabel("Train Step")
plt.show()

# %%
def projection_head(x, hidden_dim=128):
    """Constructs the projection head."""
    for i in range(2):
        x = Dense(
            hidden_dim,
            name=f"projection_layer_{i}",
            kernel_regularizer=l2(WEIGHT_DECAY),
        )(x)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)
    outputs = Dense(hidden_dim, name="projection_output")(x)
    return outputs

def build_encoder(shape, hidden_dim=128):
    inputs = Input(shape)
    s = layers.experimental.preprocessing.Rescaling(1.0 / 255)(inputs)
    #s = inputs
    x, skip_1,embed_dim_1,num_patch_x_1,num_patch_y_1 = encoder(s,filter_num_begin, depth, stack_num_down, stack_num_up, 
                      patch_size, num_heads, window_size, num_mlp, shift_window=True)
    
    #x = bottleneck(x)
    
    # Projections
    trunk_output = Flatten()(x)
    print("trunk_output",trunk_output)
    projection_outputs = projection_head(trunk_output, hidden_dim=hidden_dim)

    model = Model(inputs, projection_outputs)
    return model, skip_1,embed_dim_1,num_patch_x_1,num_patch_y_1

# %%
unet_enc, skip_connetions,embed_dim_1,num_patch_x_1,num_patch_y_1= build_encoder((IMG_WIDTH, IMG_HEIGHT, IMG_CHANNELS), hidden_dim=PROJECT_DIM)
unet_enc.summary()
# Out:
# input_size [256, 256, 3]
# num_patch_x 64
# trunk_output KerasTensor(type_spec=TensorSpec(shape=(None, 65536), dtype=tf.float32, name=None), name='flatten_5/Reshape:0', description="created by layer 'flatten_5'")
# Model: "model_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 256, 256, 3)]     0
#
#  rescaling_9 (Rescaling)     (None, 256, 256, 3)       0
#
#  patch_extract_9 (patch_extr  (None, 4096, 48)         0
#  act)
#
#  patch_embedding_9 (patch_em  (None, 4096, 128)        530560
#  bedding)
#
#  swin_transformer_block_90 (  (None, 4096, 128)        198724
#  SwinTransformerBlock)
#
#  swin_transformer_block_91 (  (None, 4096, 128)        264260
#  SwinTransformerBlock)
#
#  patch_merging_28 (patch_mer  (None, 1024, 256)        131072
#  ging)
#
#  swin_transformer_block_92 (  (None, 1024, 256)        527192
#  SwinTransformerBlock)
#
#  swin_transformer_block_93 (  (None, 1024, 256)        531288
#  SwinTransformerBlock)
#
#  patch_merging_29 (patch_mer  (None, 256, 512)         524288
#  ging)
#
#  swin_transformer_block_94 (  (None, 256, 512)         1578072
#  SwinTransformerBlock)
#
#  swin_transformer_block_95 (  (None, 256, 512)         1579096
#  SwinTransformerBlock)
#
#  patch_merging_30 (patch_mer  (None, 64, 1024)         2097152
#  ging)
#
#  swin_transformer_block_96 (  (None, 64, 1024)         5252696
#  SwinTransformerBlock)
#
#  swin_transformer_block_97 (  (None, 64, 1024)         5252952
#  SwinTransformerBlock)
#
#  flatten_5 (Flatten)         (None, 65536)             0
#
#  projection_layer_0 (Dense)  (None, 128)               8388736
#
#  batch_normalization_10 (Bat  (None, 128)              512
#  chNormalization)
#
#  activation_10 (Activation)  (None, 128)               0
#
#  projection_layer_1 (Dense)  (None, 128)               16512
#
#  batch_normalization_11 (Bat  (None, 128)              512
#  chNormalization)
#
#  activation_11 (Activation)  (None, 128)               0
#
#  projection_output (Dense)   (None, 128)               16512
#
# =================================================================
# Total params: 26,890,136
# Trainable params: 26,818,104
# Non-trainable params: 72,032
# _________________________________________________________________

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=lr_decayed_fn, momentum=0.9)
barlow_twins = BarlowTwins(unet_enc)
barlow_twins.compile(optimizer=optimizer)
if TRAIN_FLG:
    print("Training")
    barlow_twins.encoder.get_weights()[0]
    history = barlow_twins.fit(ssl_ds, epochs=2)
    barlow_twins.encoder.save('barlow_twins_unet')
    plt.plot(history.history["loss"])
    plt.grid()
    plt.title("Barlow Twin Loss")
    plt.show()
elif not TRAIN_FLG:
    print("Loading training weights")
    barlow_twins.encoder.load_weights('barlow_twins_unet')
# Out:
# Training
# Epoch 1/2
# 5/5 [==============================] - 111s 16s/step - loss: 172.3406
# Epoch 2/2
# 5/5 [==============================] - 88s 17s/step - loss: 91.3976
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Found untraced functions such as dense_9_layer_call_fn, dense_9_layer_call_and_return_conditional_losses, embedding_9_layer_call_fn, embedding_9_layer_call_and_return_conditional_losses, name0_norm1_layer_call_fn while saving (showing 5 of 202). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: barlow_twins_unet\assets
# INFO:tensorflow:Assets written to: barlow_twins_unet\assets

# %%
backbone = tf.keras.Model(
    barlow_twins.encoder.input, barlow_twins.encoder.layers[-9].output
)
backbone.layers
# Out:
# [<keras.engine.input_layer.InputLayer at 0x122ce45d580>,
#  <keras.layers.preprocessing.image_preprocessing.Rescaling at 0x122ce45d250>,
#  <keras_vision_transformer.transformer_layers.patch_extract at 0x122804d54c0>,
#  <keras_vision_transformer.transformer_layers.patch_embedding at 0x12293ed2880>,
#  <keras_vision_transformer.swin_layers.SwinTransformerBlock at 0x122d04a92b0>,
#  <keras_vision_transformer.swin_layers.SwinTransformerBlock at 0x122d0265580>,
#  <keras_vision_transformer.transformer_layers.patch_merging at 0x1229e2dccd0>,
#  <keras_vision_transformer.swin_layers.SwinTransformerBlock at 0x12293ef0040>,
#  <keras_vision_transformer.swin_layers.SwinTransformerBlock at 0x122804d5e50>,
#  <keras_vision_transformer.transformer_layers.patch_merging at 0x122afb56fa0>,
#  <keras_vision_transformer.swin_layers.SwinTransformerBlock at 0x122cfd56eb0>,
#  <keras_vision_transformer.swin_layers.SwinTransformerBlock at 0x122d6e75640>,
#  <keras_vision_transformer.transformer_layers.patch_merging at 0x122d54948b0>,
#  <keras_vision_transformer.swin_layers.SwinTransformerBlock at 0x122d54def10>,
#  <keras_vision_transformer.swin_layers.SwinTransformerBlock at 0x1229cbcf730>]

# %%
backbone.summary()
# Out:
# Model: "model_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 256, 256, 3)]     0
#
#  rescaling_9 (Rescaling)     (None, 256, 256, 3)       0
#
#  patch_extract_9 (patch_extr  (None, 4096, 48)         0
#  act)
#
#  patch_embedding_9 (patch_em  (None, 4096, 128)        530560
#  bedding)
#
#  swin_transformer_block_90 (  (None, 4096, 128)        198724
#  SwinTransformerBlock)
#
#  swin_transformer_block_91 (  (None, 4096, 128)        264260
#  SwinTransformerBlock)
#
#  patch_merging_28 (patch_mer  (None, 1024, 256)        131072
#  ging)
#
#  swin_transformer_block_92 (  (None, 1024, 256)        527192
#  SwinTransformerBlock)
#
#  swin_transformer_block_93 (  (None, 1024, 256)        531288
#  SwinTransformerBlock)
#
#  patch_merging_29 (patch_mer  (None, 256, 512)         524288
#  ging)
#
#  swin_transformer_block_94 (  (None, 256, 512)         1578072
#  SwinTransformerBlock)
#
#  swin_transformer_block_95 (  (None, 256, 512)         1579096
#  SwinTransformerBlock)
#
#  patch_merging_30 (patch_mer  (None, 64, 1024)         2097152
#  ging)
#
#  swin_transformer_block_96 (  (None, 64, 1024)         5252696
#  SwinTransformerBlock)
#
#  swin_transformer_block_97 (  (None, 64, 1024)         5252952
#  SwinTransformerBlock)
#
# =================================================================
# Total params: 18,467,352
# Trainable params: 18,395,832
# Non-trainable params: 71,520
# _________________________________________________________________

# %%
skip_connetions
# Out:
# [<KerasTensor: shape=(None, 4096, 128) dtype=float32 (created by layer 'swin_transformer_block_91')>,
#  <KerasTensor: shape=(None, 1024, 256) dtype=float32 (created by layer 'swin_transformer_block_93')>,
#  <KerasTensor: shape=(None, 256, 512) dtype=float32 (created by layer 'swin_transformer_block_95')>,
#  <KerasTensor: shape=(None, 64, 1024) dtype=float32 (created by layer 'swin_transformer_block_97')>]

# %%
new_skip_connections = [backbone.get_layer(index=5).output, 
                        backbone.get_layer(index=8).output, 
                        backbone.get_layer(index=11).output, 
                        backbone.get_layer(index=14).output]

# %%
new_skip_connections
# Out:
# [<KerasTensor: shape=(None, 4096, 128) dtype=float32 (created by layer 'swin_transformer_block_91')>,
#  <KerasTensor: shape=(None, 1024, 256) dtype=float32 (created by layer 'swin_transformer_block_93')>,
#  <KerasTensor: shape=(None, 256, 512) dtype=float32 (created by layer 'swin_transformer_block_95')>,
#  <KerasTensor: shape=(None, 64, 1024) dtype=float32 (created by layer 'swin_transformer_block_97')>]

# %%
new_skip_connections
# Out:
# [<KerasTensor: shape=(None, 4096, 128) dtype=float32 (created by layer 'swin_transformer_block_91')>,
#  <KerasTensor: shape=(None, 1024, 256) dtype=float32 (created by layer 'swin_transformer_block_93')>,
#  <KerasTensor: shape=(None, 256, 512) dtype=float32 (created by layer 'swin_transformer_block_95')>,
#  <KerasTensor: shape=(None, 64, 1024) dtype=float32 (created by layer 'swin_transformer_block_97')>]

# %%
backbone.output
# Out:
# <KerasTensor: shape=(None, 64, 1024) dtype=float32 (created by layer 'swin_transformer_block_97')>

# %%
backbone.trainable=True
#x = backbone.output
#x = bottleneck(x)
x = s_decoder( embed_dim_1,num_patch_x_1,num_patch_y_1,skip_connetions,filter_num_begin, depth, stack_num_down, stack_num_up, 
                      patch_size, num_heads, window_size, num_mlp, shift_window=True)
outputs = output(x)
model = Model(barlow_twins.encoder.input, outputs)
# Out:
# X_skip0 KerasTensor(type_spec=TensorSpec(shape=(None, 64, 1024), dtype=tf.float32, name=None), name='swin_transformer_block_97/add_1:0', description="created by layer 'swin_transformer_block_97'")
# X-decode [<KerasTensor: shape=(None, 256, 512) dtype=float32 (created by layer 'swin_transformer_block_95')>, <KerasTensor: shape=(None, 1024, 256) dtype=float32 (created by layer 'swin_transformer_block_93')>, <KerasTensor: shape=(None, 4096, 128) dtype=float32 (created by layer 'swin_transformer_block_91')>]
# depth_decode nnnnnnnnnnnn 3

# %%
model.summary()
# Out:
# Model: "model_16"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_10 (InputLayer)          [(None, 256, 256, 3  0           []
#                                 )]
#
#  rescaling_9 (Rescaling)        (None, 256, 256, 3)  0           ['input_10[0][0]']
#
#  patch_extract_9 (patch_extract  (None, 4096, 48)    0           ['rescaling_9[0][0]']
#  )
#
#  patch_embedding_9 (patch_embed  (None, 4096, 128)   530560      ['patch_extract_9[0][0]']
#  ding)
#
#  swin_transformer_block_90 (Swi  (None, 4096, 128)   198724      ['patch_embedding_9[0][0]']
#  nTransformerBlock)
#
#  swin_transformer_block_91 (Swi  (None, 4096, 128)   264260      ['swin_transformer_block_90[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_merging_28 (patch_mergin  (None, 1024, 256)   131072      ['swin_transformer_block_91[0][0]
#  g)                                                              ']
#
#  swin_transformer_block_92 (Swi  (None, 1024, 256)   527192      ['patch_merging_28[0][0]']
#  nTransformerBlock)
#
#  swin_transformer_block_93 (Swi  (None, 1024, 256)   531288      ['swin_transformer_block_92[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_merging_29 (patch_mergin  (None, 256, 512)    524288      ['swin_transformer_block_93[0][0]
#  g)                                                              ']
#
#  swin_transformer_block_94 (Swi  (None, 256, 512)    1578072     ['patch_merging_29[0][0]']
#  nTransformerBlock)
#
#  swin_transformer_block_95 (Swi  (None, 256, 512)    1579096     ['swin_transformer_block_94[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_merging_30 (patch_mergin  (None, 64, 1024)    2097152     ['swin_transformer_block_95[0][0]
#  g)                                                              ']
#
#  swin_transformer_block_96 (Swi  (None, 64, 1024)    5252696     ['patch_merging_30[0][0]']
#  nTransformerBlock)
#
#  swin_transformer_block_97 (Swi  (None, 64, 1024)    5252952     ['swin_transformer_block_96[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_22 (patch_expa  (None, 256, 512)    2097152     ['swin_transformer_block_97[0][0]
#  nding)                                                          ']
#
#  swin_decoder_concat_0 (Concate  (None, 256, 1024)   0           ['patch_expanding_22[0][0]',
#  nate)                                                            'swin_transformer_block_95[0][0]
#                                                                  ']
#
#  swin_decoder_concat_linear_pro  (None, 256, 512)    524288      ['swin_decoder_concat_0[0][0]']
#  j_0 (Dense)
#
#  swin_transformer_block_98 (Swi  (None, 256, 512)    1578072     ['swin_decoder_concat_linear_proj
#  nTransformerBlock)                                              _0[0][0]']
#
#  swin_transformer_block_99 (Swi  (None, 256, 512)    1579096     ['swin_transformer_block_98[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_23 (patch_expa  (None, 1024, 256)   524288      ['swin_transformer_block_99[0][0]
#  nding)                                                          ']
#
#  swin_decoder_concat_1 (Concate  (None, 1024, 512)   0           ['patch_expanding_23[0][0]',
#  nate)                                                            'swin_transformer_block_93[0][0]
#                                                                  ']
#
#  swin_decoder_concat_linear_pro  (None, 1024, 256)   131072      ['swin_decoder_concat_1[0][0]']
#  j_1 (Dense)
#
#  swin_transformer_block_100 (Sw  (None, 1024, 256)   527192      ['swin_decoder_concat_linear_proj
#  inTransformerBlock)                                             _1[0][0]']
#
#  swin_transformer_block_101 (Sw  (None, 1024, 256)   531288      ['swin_transformer_block_100[0][0
#  inTransformerBlock)                                             ]']
#
#  patch_expanding_24 (patch_expa  (None, 4096, 128)   131072      ['swin_transformer_block_101[0][0
#  nding)                                                          ]']
#
#  swin_decoder_concat_2 (Concate  (None, 4096, 256)   0           ['patch_expanding_24[0][0]',
#  nate)                                                            'swin_transformer_block_91[0][0]
#                                                                  ']
#
#  swin_decoder_concat_linear_pro  (None, 4096, 128)   32768       ['swin_decoder_concat_2[0][0]']
#  j_2 (Dense)
#
#  swin_transformer_block_102 (Sw  (None, 4096, 128)   198360      ['swin_decoder_concat_linear_proj
#  inTransformerBlock)                                             _2[0][0]']
#
#  swin_transformer_block_103 (Sw  (None, 4096, 128)   214744      ['swin_transformer_block_102[0][0
#  inTransformerBlock)                                             ]']
#
#  patch_expanding_25 (patch_expa  (None, 256, 256, 32  65536      ['swin_transformer_block_103[0][0
#  nding)                         )                                ]']
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 1)  33          ['patch_expanding_25[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 256, 256, 1)  4          ['conv2d_3[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 256, 256, 1)  0           ['batch_normalization_12[0][0]']
#
# ==================================================================================================
# Total params: 26,602,317
# Trainable params: 26,509,195
# Non-trainable params: 93,122
# __________________________________________________________________________________________________

# %%
def iou_metric(y_true_in, y_pred_in, print_table=False):
    labels = label(y_true_in > 0.5)
    y_pred = label(y_pred_in > 0.5)
    
    true_objects = len(np.unique(labels))
    pred_objects = len(np.unique(y_pred))

    intersection = np.histogram2d(labels.flatten(), y_pred.flatten(), bins=(true_objects, pred_objects))[0]

    # Compute areas (needed for finding the union between all objects)
    area_true = np.histogram(labels, bins = true_objects)[0]
    area_pred = np.histogram(y_pred, bins = pred_objects)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    # Compute union
    union = area_true + area_pred - intersection

    # Exclude background from the analysis
    intersection = intersection[1:,1:]
    union = union[1:,1:]
    union[union == 0] = 1e-9

    # Compute the intersection over union
    iou = intersection / union
    #print('IOU {}'.format(iou))
    # Precision helper function
    def precision_at(threshold, iou):
        matches = iou > threshold
        true_positives = np.sum(matches, axis=1) == 1   # Correct objects
        false_positives = np.sum(matches, axis=0) == 0  # Missed objects
        false_negatives = np.sum(matches, axis=1) == 0  # Extra objects
        tp, fp, fn = np.sum(true_positives), np.sum(false_positives), np.sum(false_negatives)
        return tp, fp, fn

    # Loop over IoU thresholds
    prec = []
    if print_table:
        print("Thresh\tTP\tFP\tFN\tPrec.")
    for t in np.arange(0.5, 1.0, 0.05):
        tp, fp, fn = precision_at(t, iou)
        if (tp + fp + fn) > 0:
            p = tp / (tp + fp + fn)
        else:
            p = 0
        if print_table:
            print("{:1.3f}\t{}\t{}\t{}\t{:1.3f}".format(t, tp, fp, fn, p))
        prec.append(p)
    
    if print_table:
        print("AP\t-\t-\t-\t{:1.3f}".format(np.mean(prec)))
    return np.mean(prec)

def iou_metric_batch(y_true_in, y_pred_in):
    batch_size = y_true_in.shape[0]
    value = 0.
    for batch in range(batch_size):
        value = value + iou_metric(y_true_in[batch], y_pred_in[batch])
    return value/batch_size

def my_iou_metric(label, pred):
    metric_value = tf.py_function(iou_metric_batch, [label, pred], tf.float32)
    return metric_value

def my_iou_metric_loss(label, pred):
    loss = 1-tf.py_function(iou_metric_batch, [label, pred], tf.float32)
    #loss = -tf.map_fn(my_iou_metric_loss(label, pred), tf.range(tf.shape(pred)[0]))
    loss.set_shape((None,))

    return loss

def dice_coeff(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    score = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return score

def haud_dist(y_true, y_pred):
    y_true = np.squeeze(y_true)
    y_pred = np.squeeze(y_pred)
    
    return hausdorff_distance(y_true,y_pred)

def haud_dist_batch(y_true, y_pred):
    if len(y_true.shape)==2:
        return haud_dist(y_true, y_pred)
    else:
        batch_size = y_true.shape[0]
    hd = 0.
    for batch in range(batch_size):
        hd = hd + haud_dist(y_true[batch], y_pred[batch])
    return hd/batch_size

def my_haud_dist(label, pred):
    metric_value = tf.py_function(haud_dist_batch, [label, pred], tf.float32)
    return metric_value

def evalResult(gt,pred,target_size=(256,256),flag_multi_class = False,num_class = 2):
    gt = np.squeeze(gt)
    pred = np.squeeze(pred)
    
    acc = Accuracy()
    acc.update_state(np.squeeze(gt), np.squeeze(pred))
    r_acc = acc.result().numpy()
    
    pr = Precision()
    pr.update_state(np.squeeze(gt), np.squeeze(pred))
    r_pr = pr.result().numpy()
    
    rc = Recall()
    rc.update_state(np.squeeze(gt), np.squeeze(pred))
    r_rc = rc.result().numpy()
    
    mi = MeanIoU(num_class)
    mi.update_state(np.squeeze(gt), np.squeeze(pred))
    r_mi = mi.result().numpy()
    
    dc = 0.
    for img in range(gt.shape[0]):
        dc = dc + dice_coeff(gt[img], pred[img]).numpy()
    dc = dc / gt.shape[0]
    
    hd = haud_dist_batch(gt,pred)
    
    miou = iou_metric_batch(gt,pred)
    
    mae = MeanAbsoluteError()
    r_mae = mae(np.squeeze(gt), np.squeeze(pred)).numpy()

    print("Accuracy=",r_acc, "Precision=",r_pr, "Recall=",r_rc, "MeanIoU=",r_mi, "DiceCoefficient=",dc, "HD=",hd, "MyIoU=",miou, "MAE=",r_mae)

# %%
def focal_loss(target_tensor, prediction_tensor, weights=None, alpha=0.25, gamma=2):
    sigmoid_p = tf.nn.sigmoid(prediction_tensor)
    zeros = array_ops.zeros_like(sigmoid_p, dtype=sigmoid_p.dtype)
    
    # For poitive prediction, only need consider front part loss, back part is 0;
    # target_tensor > zeros <=> z=1, so poitive coefficient = z - p.
    pos_p_sub = array_ops.where(target_tensor > zeros, target_tensor - sigmoid_p, zeros)
    
    # For negative prediction, only need consider back part loss, front part is 0;
    # target_tensor > zeros <=> z=1, so negative coefficient = 0.
    neg_p_sub = array_ops.where(target_tensor > zeros, zeros, sigmoid_p)
    per_entry_cross_ent = - alpha * (pos_p_sub ** gamma) * tf.math.log(tf.clip_by_value(sigmoid_p, 1e-8, 1.0))                           - (1 - alpha) * (neg_p_sub ** gamma) * tf.math.log(tf.clip_by_value(1.0 - sigmoid_p, 1e-8, 1.0))
    return tf.reduce_sum(per_entry_cross_ent)

def mean_iou_loss(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.compat.v1.to_int32(y_pred > t)
        score, up_opt = tf.compat.v1.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return -tf.math.log(K.mean(K.stack(prec), axis=0))

def dice_loss(y_true, y_pred):
    loss = 1 - dice_coeff(y_true, y_pred)
    return loss

def bce_dice_loss(y_true, y_pred):
    loss = 0.4*categorical_crossentropy(y_true, y_pred) + 0.6*dice_loss(y_true, y_pred)
    return loss

def bce_dice_loss2(y_true, y_pred):
    fl = focal_loss(y_true, y_pred, gamma=5)
    loss = 0.2*categorical_crossentropy(y_true, y_pred) + 0.3*dice_loss(y_true, y_pred) + 0.5*fl
    return loss

# %%
log_path = "logs/"
keyname = "BT-Unet"
cur_date = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tb_log_dir = log_path + "fit/" + keyname + '_' + cur_date 
tensorboard_callback = TensorBoard(log_dir=tb_log_dir, histogram_freq=0)
model_checkpoint = ModelCheckpoint('model_'+keyname+'.hdf5', monitor='loss',verbose=1, save_best_only=True)
early_stopping = EarlyStopping(monitor='loss', verbose=1, patience=20)
csv_logger = CSVLogger(log_path + keyname + '_' + cur_date + '.log', separator=',', append=False)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10)

# %%
model.compile(
    loss=bce_dice_loss,
    optimizer=Adam(),
    metrics=['accuracy', Precision(), MeanIoU(num_classes=2), Recall(), dice_coeff, MeanAbsoluteError(), my_haud_dist, my_iou_metric]
   )
if TRAIN_FLG:
    print("Training")
    callbacks = [
        model_checkpoint,
        reduce_lr,
        csv_logger,
        tensorboard_callback,
        early_stopping
    ]
    X_train_20 = X_train[:int(X_train.shape[0]*0.2)]
    Y_train_20 = Y_train[:int(Y_train.shape[0]*0.2)]
    results = model.fit(X_train_20, Y_train_20, validation_split=val_split, batch_size=8, epochs=200)
elif not TRAIN_FLG:
    print("Loading training weights")
    model.load_weights('model_'+keyname+'.hdf5')
# Out:
# Training
# Epoch 1/200
# WARNING:tensorflow:5 out of the last 14 calls to <function Model.make_train_function.<locals>.train_function at 0x00000122A6BB2EE0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 14 calls to <function Model.make_train_function.<locals>.train_function at 0x00000122A6BB2EE0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 44s 44s/step - loss: 0.1892 - accuracy: 0.7746 - precision_3: 0.8945 - mean_io_u_3: 0.1466 - recall_3: 0.7721 - dice_coeff: 0.6846 - mean_absolute_error: 0.3842 - my_haud_dist: 8.7871 - my_iou_metric: 3.6412e-04 - val_loss: 0.0198 - val_accuracy: 0.9520 - val_precision_3: 0.9550 - val_mean_io_u_3: 0.5532 - val_recall_3: 0.9786 - val_dice_coeff: 0.9669 - val_mean_absolute_error: 0.0476 - val_my_haud_dist: 5.0399 - val_my_iou_metric: 0.1018
# Epoch 2/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1590 - accuracy: 0.9291 - precision_3: 0.9894 - mean_io_u_3: 0.1466 - recall_3: 0.9094 - dice_coeff: 0.7350 - mean_absolute_error: 0.3222 - my_haud_dist: 6.4030 - my_iou_metric: 0.0121 - val_loss: 0.0296 - val_accuracy: 0.9287 - val_precision_3: 0.9110 - val_mean_io_u_3: 0.3242 - val_recall_3: 0.9970 - val_dice_coeff: 0.9506 - val_mean_absolute_error: 0.0736 - val_my_haud_dist: 4.0033 - val_my_iou_metric: 0.0799
# Epoch 3/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1604 - accuracy: 0.9295 - precision_3: 0.9795 - mean_io_u_3: 0.1466 - recall_3: 0.9194 - dice_coeff: 0.7327 - mean_absolute_error: 0.3253 - my_haud_dist: 7.0665 - my_iou_metric: 0.0127 - val_loss: 0.0230 - val_accuracy: 0.9444 - val_precision_3: 0.9342 - val_mean_io_u_3: 0.3874 - val_recall_3: 0.9916 - val_dice_coeff: 0.9616 - val_mean_absolute_error: 0.0563 - val_my_haud_dist: 4.7295 - val_my_iou_metric: 0.0875
# Epoch 4/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1573 - accuracy: 0.9484 - precision_3: 0.9800 - mean_io_u_3: 0.1466 - recall_3: 0.9462 - dice_coeff: 0.7379 - mean_absolute_error: 0.3194 - my_haud_dist: 7.3364 - my_iou_metric: 0.0261 - val_loss: 0.0176 - val_accuracy: 0.9578 - val_precision_3: 0.9631 - val_mean_io_u_3: 0.4529 - val_recall_3: 0.9781 - val_dice_coeff: 0.9707 - val_mean_absolute_error: 0.0420 - val_my_haud_dist: 4.1479 - val_my_iou_metric: 0.1000
# Epoch 5/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1536 - accuracy: 0.9538 - precision_3: 0.9873 - mean_io_u_3: 0.1466 - recall_3: 0.9468 - dice_coeff: 0.7439 - mean_absolute_error: 0.3120 - my_haud_dist: 6.0074 - my_iou_metric: 0.0731 - val_loss: 0.0151 - val_accuracy: 0.9657 - val_precision_3: 0.9822 - val_mean_io_u_3: 0.2328 - val_recall_3: 0.9693 - val_dice_coeff: 0.9748 - val_mean_absolute_error: 0.0356 - val_my_haud_dist: 4.6936 - val_my_iou_metric: 0.1548
# Epoch 6/200
# 1/1 [==============================] - 15s 15s/step - loss: 0.1537 - accuracy: 0.9491 - precision_3: 0.9923 - mean_io_u_3: 0.1466 - recall_3: 0.9353 - dice_coeff: 0.7438 - mean_absolute_error: 0.3118 - my_haud_dist: 6.2689 - my_iou_metric: 0.0583 - val_loss: 0.0154 - val_accuracy: 0.9652 - val_precision_3: 0.9863 - val_mean_io_u_3: 0.1447 - val_recall_3: 0.9644 - val_dice_coeff: 0.9743 - val_mean_absolute_error: 0.0361 - val_my_haud_dist: 4.0806 - val_my_iou_metric: 0.1500
# Epoch 7/200
# 1/1 [==============================] - 15s 15s/step - loss: 0.1533 - accuracy: 0.9465 - precision_3: 0.9962 - mean_io_u_3: 0.1466 - recall_3: 0.9278 - dice_coeff: 0.7446 - mean_absolute_error: 0.3108 - my_haud_dist: 6.0710 - my_iou_metric: 0.0536 - val_loss: 0.0153 - val_accuracy: 0.9659 - val_precision_3: 0.9885 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9632 - val_dice_coeff: 0.9746 - val_mean_absolute_error: 0.0357 - val_my_haud_dist: 4.0290 - val_my_iou_metric: 0.2083
# Epoch 8/200
# 1/1 [==============================] - 14s 14s/step - loss: 0.1529 - accuracy: 0.9447 - precision_3: 0.9975 - mean_io_u_3: 0.1466 - recall_3: 0.9240 - dice_coeff: 0.7452 - mean_absolute_error: 0.3100 - my_haud_dist: 6.0723 - my_iou_metric: 0.0531 - val_loss: 0.0148 - val_accuracy: 0.9685 - val_precision_3: 0.9908 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9646 - val_dice_coeff: 0.9753 - val_mean_absolute_error: 0.0347 - val_my_haud_dist: 4.2329 - val_my_iou_metric: 0.1417
# Epoch 9/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1524 - accuracy: 0.9462 - precision_3: 0.9984 - mean_io_u_3: 0.1466 - recall_3: 0.9253 - dice_coeff: 0.7459 - mean_absolute_error: 0.3091 - my_haud_dist: 6.1750 - my_iou_metric: 0.0531 - val_loss: 0.0145 - val_accuracy: 0.9714 - val_precision_3: 0.9927 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9669 - val_dice_coeff: 0.9759 - val_mean_absolute_error: 0.0338 - val_my_haud_dist: 4.5252 - val_my_iou_metric: 0.1333
# Epoch 10/200
# 1/1 [==============================] - 15s 15s/step - loss: 0.1520 - accuracy: 0.9500 - precision_3: 0.9990 - mean_io_u_3: 0.1466 - recall_3: 0.9301 - dice_coeff: 0.7466 - mean_absolute_error: 0.3082 - my_haud_dist: 5.9470 - my_iou_metric: 0.0343 - val_loss: 0.0143 - val_accuracy: 0.9728 - val_precision_3: 0.9930 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9686 - val_dice_coeff: 0.9761 - val_mean_absolute_error: 0.0335 - val_my_haud_dist: 4.5920 - val_my_iou_metric: 0.1500
# Epoch 11/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1517 - accuracy: 0.9546 - precision_3: 0.9993 - mean_io_u_3: 0.1466 - recall_3: 0.9364 - dice_coeff: 0.7472 - mean_absolute_error: 0.3076 - my_haud_dist: 5.8610 - my_iou_metric: 0.0431 - val_loss: 0.0142 - val_accuracy: 0.9741 - val_precision_3: 0.9930 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9705 - val_dice_coeff: 0.9764 - val_mean_absolute_error: 0.0332 - val_my_haud_dist: 4.4961 - val_my_iou_metric: 0.1339
# Epoch 12/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1511 - accuracy: 0.9585 - precision_3: 0.9993 - mean_io_u_3: 0.1466 - recall_3: 0.9419 - dice_coeff: 0.7481 - mean_absolute_error: 0.3065 - my_haud_dist: 5.7316 - my_iou_metric: 0.0640 - val_loss: 0.0144 - val_accuracy: 0.9757 - val_precision_3: 0.9923 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9734 - val_dice_coeff: 0.9760 - val_mean_absolute_error: 0.0337 - val_my_haud_dist: 4.4364 - val_my_iou_metric: 0.2667
# Epoch 13/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1510 - accuracy: 0.9624 - precision_3: 0.9991 - mean_io_u_3: 0.1466 - recall_3: 0.9476 - dice_coeff: 0.7483 - mean_absolute_error: 0.3062 - my_haud_dist: 5.7750 - my_iou_metric: 0.0794 - val_loss: 0.0146 - val_accuracy: 0.9761 - val_precision_3: 0.9912 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9750 - val_dice_coeff: 0.9756 - val_mean_absolute_error: 0.0344 - val_my_haud_dist: 4.2056 - val_my_iou_metric: 0.1339
# Epoch 14/200
# 1/1 [==============================] - 15s 15s/step - loss: 0.1506 - accuracy: 0.9656 - precision_3: 0.9990 - mean_io_u_3: 0.1466 - recall_3: 0.9523 - dice_coeff: 0.7490 - mean_absolute_error: 0.3054 - my_haud_dist: 5.6919 - my_iou_metric: 0.0794 - val_loss: 0.0153 - val_accuracy: 0.9768 - val_precision_3: 0.9899 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9773 - val_dice_coeff: 0.9745 - val_mean_absolute_error: 0.0359 - val_my_haud_dist: 4.0133 - val_my_iou_metric: 0.1429
# Epoch 15/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1502 - accuracy: 0.9676 - precision_3: 0.9987 - mean_io_u_3: 0.1466 - recall_3: 0.9553 - dice_coeff: 0.7497 - mean_absolute_error: 0.3046 - my_haud_dist: 5.8383 - my_iou_metric: 0.1265 - val_loss: 0.0168 - val_accuracy: 0.9779 - val_precision_3: 0.9886 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9803 - val_dice_coeff: 0.9720 - val_mean_absolute_error: 0.0395 - val_my_haud_dist: 3.8626 - val_my_iou_metric: 0.2667
# Epoch 16/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1499 - accuracy: 0.9698 - precision_3: 0.9984 - mean_io_u_3: 0.1466 - recall_3: 0.9588 - dice_coeff: 0.7501 - mean_absolute_error: 0.3041 - my_haud_dist: 5.8995 - my_iou_metric: 0.0955 - val_loss: 0.0197 - val_accuracy: 0.9791 - val_precision_3: 0.9882 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9823 - val_dice_coeff: 0.9672 - val_mean_absolute_error: 0.0461 - val_my_haud_dist: 3.6264 - val_my_iou_metric: 0.5000
# Epoch 17/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1495 - accuracy: 0.9720 - precision_3: 0.9980 - mean_io_u_3: 0.1466 - recall_3: 0.9624 - dice_coeff: 0.7509 - mean_absolute_error: 0.3032 - my_haud_dist: 5.8284 - my_iou_metric: 0.1705 - val_loss: 0.0252 - val_accuracy: 0.9802 - val_precision_3: 0.9885 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9836 - val_dice_coeff: 0.9580 - val_mean_absolute_error: 0.0588 - val_my_haud_dist: 3.4583 - val_my_iou_metric: 0.3333
# Epoch 18/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1490 - accuracy: 0.9745 - precision_3: 0.9974 - mean_io_u_3: 0.1466 - recall_3: 0.9664 - dice_coeff: 0.7516 - mean_absolute_error: 0.3024 - my_haud_dist: 5.8961 - my_iou_metric: 0.1125 - val_loss: 0.0356 - val_accuracy: 0.9811 - val_precision_3: 0.9891 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9842 - val_dice_coeff: 0.9407 - val_mean_absolute_error: 0.0822 - val_my_haud_dist: 3.4213 - val_my_iou_metric: 0.2000
# Epoch 19/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1488 - accuracy: 0.9767 - precision_3: 0.9967 - mean_io_u_3: 0.1466 - recall_3: 0.9702 - dice_coeff: 0.7520 - mean_absolute_error: 0.3018 - my_haud_dist: 5.8940 - my_iou_metric: 0.2381 - val_loss: 0.0504 - val_accuracy: 0.9811 - val_precision_3: 0.9901 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9833 - val_dice_coeff: 0.9161 - val_mean_absolute_error: 0.1146 - val_my_haud_dist: 3.4592 - val_my_iou_metric: 0.1833
# Epoch 20/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1487 - accuracy: 0.9784 - precision_3: 0.9959 - mean_io_u_3: 0.1466 - recall_3: 0.9733 - dice_coeff: 0.7522 - mean_absolute_error: 0.3016 - my_haud_dist: 5.6369 - my_iou_metric: 0.3500 - val_loss: 0.0553 - val_accuracy: 0.9813 - val_precision_3: 0.9906 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9830 - val_dice_coeff: 0.9079 - val_mean_absolute_error: 0.1251 - val_my_haud_dist: 3.4415 - val_my_iou_metric: 0.2500
# Epoch 21/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1488 - accuracy: 0.9789 - precision_3: 0.9958 - mean_io_u_3: 0.1466 - recall_3: 0.9743 - dice_coeff: 0.7519 - mean_absolute_error: 0.3019 - my_haud_dist: 5.7390 - my_iou_metric: 0.2500 - val_loss: 0.0420 - val_accuracy: 0.9822 - val_precision_3: 0.9907 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9842 - val_dice_coeff: 0.9300 - val_mean_absolute_error: 0.0964 - val_my_haud_dist: 3.3017 - val_my_iou_metric: 0.3750
# Epoch 22/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1484 - accuracy: 0.9779 - precision_3: 0.9967 - mean_io_u_3: 0.1466 - recall_3: 0.9720 - dice_coeff: 0.7526 - mean_absolute_error: 0.3010 - my_haud_dist: 5.6309 - my_iou_metric: 0.2000 - val_loss: 0.0320 - val_accuracy: 0.9827 - val_precision_3: 0.9913 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9842 - val_dice_coeff: 0.9467 - val_mean_absolute_error: 0.0741 - val_my_haud_dist: 3.1869 - val_my_iou_metric: 0.3500
# Epoch 23/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1484 - accuracy: 0.9766 - precision_3: 0.9975 - mean_io_u_3: 0.1466 - recall_3: 0.9693 - dice_coeff: 0.7527 - mean_absolute_error: 0.3009 - my_haud_dist: 5.6992 - my_iou_metric: 0.1429 - val_loss: 0.0273 - val_accuracy: 0.9831 - val_precision_3: 0.9918 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9844 - val_dice_coeff: 0.9545 - val_mean_absolute_error: 0.0636 - val_my_haud_dist: 3.1628 - val_my_iou_metric: 0.2917
# Epoch 24/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1484 - accuracy: 0.9753 - precision_3: 0.9981 - mean_io_u_3: 0.1466 - recall_3: 0.9670 - dice_coeff: 0.7527 - mean_absolute_error: 0.3008 - my_haud_dist: 5.6771 - my_iou_metric: 0.2250 - val_loss: 0.0262 - val_accuracy: 0.9837 - val_precision_3: 0.9928 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9842 - val_dice_coeff: 0.9563 - val_mean_absolute_error: 0.0611 - val_my_haud_dist: 3.1401 - val_my_iou_metric: 0.4167
# Epoch 25/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1484 - accuracy: 0.9741 - precision_3: 0.9983 - mean_io_u_3: 0.1466 - recall_3: 0.9650 - dice_coeff: 0.7527 - mean_absolute_error: 0.3008 - my_haud_dist: 5.6929 - my_iou_metric: 0.1429 - val_loss: 0.0275 - val_accuracy: 0.9842 - val_precision_3: 0.9939 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9838 - val_dice_coeff: 0.9541 - val_mean_absolute_error: 0.0639 - val_my_haud_dist: 3.1315 - val_my_iou_metric: 0.3750
# Epoch 26/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1483 - accuracy: 0.9741 - precision_3: 0.9986 - mean_io_u_3: 0.1466 - recall_3: 0.9647 - dice_coeff: 0.7528 - mean_absolute_error: 0.3006 - my_haud_dist: 5.7203 - my_iou_metric: 0.1833 - val_loss: 0.0307 - val_accuracy: 0.9847 - val_precision_3: 0.9947 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9837 - val_dice_coeff: 0.9489 - val_mean_absolute_error: 0.0710 - val_my_haud_dist: 3.1707 - val_my_iou_metric: 0.4167
# Epoch 27/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1482 - accuracy: 0.9749 - precision_3: 0.9988 - mean_io_u_3: 0.1466 - recall_3: 0.9656 - dice_coeff: 0.7530 - mean_absolute_error: 0.3003 - my_haud_dist: 5.6783 - my_iou_metric: 0.2500 - val_loss: 0.0351 - val_accuracy: 0.9847 - val_precision_3: 0.9949 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9835 - val_dice_coeff: 0.9415 - val_mean_absolute_error: 0.0808 - val_my_haud_dist: 3.2420 - val_my_iou_metric: 0.3750
# Epoch 28/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1481 - accuracy: 0.9759 - precision_3: 0.9989 - mean_io_u_3: 0.1466 - recall_3: 0.9670 - dice_coeff: 0.7531 - mean_absolute_error: 0.3001 - my_haud_dist: 5.6419 - my_iou_metric: 0.5833 - val_loss: 0.0395 - val_accuracy: 0.9849 - val_precision_3: 0.9951 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9835 - val_dice_coeff: 0.9341 - val_mean_absolute_error: 0.0907 - val_my_haud_dist: 3.3203 - val_my_iou_metric: 0.2500
# Epoch 29/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1481 - accuracy: 0.9769 - precision_3: 0.9988 - mean_io_u_3: 0.1466 - recall_3: 0.9684 - dice_coeff: 0.7532 - mean_absolute_error: 0.3001 - my_haud_dist: 5.6188 - my_iou_metric: 0.1714 - val_loss: 0.0422 - val_accuracy: 0.9850 - val_precision_3: 0.9952 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9837 - val_dice_coeff: 0.9297 - val_mean_absolute_error: 0.0965 - val_my_haud_dist: 3.3607 - val_my_iou_metric: 0.2500
# Epoch 30/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1481 - accuracy: 0.9780 - precision_3: 0.9986 - mean_io_u_3: 0.1466 - recall_3: 0.9702 - dice_coeff: 0.7532 - mean_absolute_error: 0.3000 - my_haud_dist: 5.5925 - my_iou_metric: 0.2917 - val_loss: 0.0426 - val_accuracy: 0.9852 - val_precision_3: 0.9951 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9839 - val_dice_coeff: 0.9290 - val_mean_absolute_error: 0.0974 - val_my_haud_dist: 3.3418 - val_my_iou_metric: 0.2667
# Epoch 31/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1480 - accuracy: 0.9786 - precision_3: 0.9986 - mean_io_u_3: 0.1466 - recall_3: 0.9711 - dice_coeff: 0.7533 - mean_absolute_error: 0.2998 - my_haud_dist: 5.6199 - my_iou_metric: 0.2667 - val_loss: 0.0418 - val_accuracy: 0.9853 - val_precision_3: 0.9951 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9842 - val_dice_coeff: 0.9303 - val_mean_absolute_error: 0.0958 - val_my_haud_dist: 3.3305 - val_my_iou_metric: 0.3750
# Epoch 32/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1480 - accuracy: 0.9787 - precision_3: 0.9986 - mean_io_u_3: 0.1466 - recall_3: 0.9713 - dice_coeff: 0.7534 - mean_absolute_error: 0.2997 - my_haud_dist: 5.6390 - my_iou_metric: 0.2917 - val_loss: 0.0410 - val_accuracy: 0.9854 - val_precision_3: 0.9950 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9843 - val_dice_coeff: 0.9316 - val_mean_absolute_error: 0.0941 - val_my_haud_dist: 3.3315 - val_my_iou_metric: 0.4167
# Epoch 33/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1479 - accuracy: 0.9788 - precision_3: 0.9986 - mean_io_u_3: 0.1466 - recall_3: 0.9713 - dice_coeff: 0.7535 - mean_absolute_error: 0.2995 - my_haud_dist: 5.6147 - my_iou_metric: 0.2917 - val_loss: 0.0409 - val_accuracy: 0.9854 - val_precision_3: 0.9949 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9845 - val_dice_coeff: 0.9318 - val_mean_absolute_error: 0.0938 - val_my_haud_dist: 3.3440 - val_my_iou_metric: 0.4167
# Epoch 34/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1479 - accuracy: 0.9789 - precision_3: 0.9986 - mean_io_u_3: 0.1466 - recall_3: 0.9714 - dice_coeff: 0.7536 - mean_absolute_error: 0.2994 - my_haud_dist: 5.6407 - my_iou_metric: 0.4167 - val_loss: 0.0416 - val_accuracy: 0.9856 - val_precision_3: 0.9950 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9846 - val_dice_coeff: 0.9307 - val_mean_absolute_error: 0.0953 - val_my_haud_dist: 3.3642 - val_my_iou_metric: 0.4167
# Epoch 35/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1478 - accuracy: 0.9788 - precision_3: 0.9986 - mean_io_u_3: 0.1466 - recall_3: 0.9714 - dice_coeff: 0.7536 - mean_absolute_error: 0.2993 - my_haud_dist: 5.6739 - my_iou_metric: 0.4167 - val_loss: 0.0430 - val_accuracy: 0.9856 - val_precision_3: 0.9949 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9847 - val_dice_coeff: 0.9284 - val_mean_absolute_error: 0.0983 - val_my_haud_dist: 3.3875 - val_my_iou_metric: 0.4167
# Epoch 36/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1478 - accuracy: 0.9789 - precision_3: 0.9986 - mean_io_u_3: 0.1466 - recall_3: 0.9715 - dice_coeff: 0.7537 - mean_absolute_error: 0.2992 - my_haud_dist: 5.6716 - my_iou_metric: 0.5000 - val_loss: 0.0449 - val_accuracy: 0.9856 - val_precision_3: 0.9949 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9848 - val_dice_coeff: 0.9251 - val_mean_absolute_error: 0.1026 - val_my_haud_dist: 3.4109 - val_my_iou_metric: 0.5000
# Epoch 37/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1477 - accuracy: 0.9790 - precision_3: 0.9986 - mean_io_u_3: 0.1466 - recall_3: 0.9717 - dice_coeff: 0.7538 - mean_absolute_error: 0.2990 - my_haud_dist: 5.6455 - my_iou_metric: 0.7500 - val_loss: 0.0474 - val_accuracy: 0.9857 - val_precision_3: 0.9949 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9850 - val_dice_coeff: 0.9209 - val_mean_absolute_error: 0.1080 - val_my_haud_dist: 3.4336 - val_my_iou_metric: 0.7500
# Epoch 38/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1477 - accuracy: 0.9792 - precision_3: 0.9985 - mean_io_u_3: 0.1466 - recall_3: 0.9720 - dice_coeff: 0.7538 - mean_absolute_error: 0.2989 - my_haud_dist: 5.6505 - my_iou_metric: 0.6667 - val_loss: 0.0503 - val_accuracy: 0.9857 - val_precision_3: 0.9948 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9850 - val_dice_coeff: 0.9161 - val_mean_absolute_error: 0.1143 - val_my_haud_dist: 3.4559 - val_my_iou_metric: 1.0000
# Epoch 39/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1477 - accuracy: 0.9793 - precision_3: 0.9984 - mean_io_u_3: 0.1466 - recall_3: 0.9723 - dice_coeff: 0.7539 - mean_absolute_error: 0.2988 - my_haud_dist: 5.6331 - my_iou_metric: 0.4167 - val_loss: 0.0534 - val_accuracy: 0.9858 - val_precision_3: 0.9949 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9851 - val_dice_coeff: 0.9109 - val_mean_absolute_error: 0.1209 - val_my_haud_dist: 3.4780 - val_my_iou_metric: 1.0000
# Epoch 40/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1476 - accuracy: 0.9796 - precision_3: 0.9984 - mean_io_u_3: 0.1466 - recall_3: 0.9726 - dice_coeff: 0.7540 - mean_absolute_error: 0.2987 - my_haud_dist: 5.5940 - my_iou_metric: 0.5000 - val_loss: 0.0565 - val_accuracy: 0.9860 - val_precision_3: 0.9951 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9852 - val_dice_coeff: 0.9058 - val_mean_absolute_error: 0.1275 - val_my_haud_dist: 3.4988 - val_my_iou_metric: 1.0000
# Epoch 41/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1476 - accuracy: 0.9798 - precision_3: 0.9984 - mean_io_u_3: 0.1466 - recall_3: 0.9730 - dice_coeff: 0.7541 - mean_absolute_error: 0.2985 - my_haud_dist: 5.5556 - my_iou_metric: 0.5000 - val_loss: 0.0594 - val_accuracy: 0.9862 - val_precision_3: 0.9952 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9853 - val_dice_coeff: 0.9010 - val_mean_absolute_error: 0.1337 - val_my_haud_dist: 3.5166 - val_my_iou_metric: 0.7500
# Epoch 42/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1475 - accuracy: 0.9803 - precision_3: 0.9984 - mean_io_u_3: 0.1466 - recall_3: 0.9736 - dice_coeff: 0.7541 - mean_absolute_error: 0.2984 - my_haud_dist: 5.5419 - my_iou_metric: 0.7500 - val_loss: 0.0621 - val_accuracy: 0.9863 - val_precision_3: 0.9951 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9856 - val_dice_coeff: 0.8964 - val_mean_absolute_error: 0.1394 - val_my_haud_dist: 3.5311 - val_my_iou_metric: 0.7500
# Epoch 43/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1475 - accuracy: 0.9807 - precision_3: 0.9985 - mean_io_u_3: 0.1466 - recall_3: 0.9742 - dice_coeff: 0.7542 - mean_absolute_error: 0.2983 - my_haud_dist: 5.5656 - my_iou_metric: 0.7500 - val_loss: 0.0648 - val_accuracy: 0.9863 - val_precision_3: 0.9951 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9857 - val_dice_coeff: 0.8919 - val_mean_absolute_error: 0.1451 - val_my_haud_dist: 3.5452 - val_my_iou_metric: 0.6667
# Epoch 44/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1474 - accuracy: 0.9813 - precision_3: 0.9985 - mean_io_u_3: 0.1466 - recall_3: 0.9751 - dice_coeff: 0.7543 - mean_absolute_error: 0.2982 - my_haud_dist: 5.6038 - my_iou_metric: 0.5000 - val_loss: 0.0679 - val_accuracy: 0.9866 - val_precision_3: 0.9953 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9858 - val_dice_coeff: 0.8869 - val_mean_absolute_error: 0.1513 - val_my_haud_dist: 3.5652 - val_my_iou_metric: 0.5000
# Epoch 45/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1474 - accuracy: 0.9819 - precision_3: 0.9985 - mean_io_u_3: 0.1466 - recall_3: 0.9759 - dice_coeff: 0.7543 - mean_absolute_error: 0.2981 - my_haud_dist: 5.6315 - my_iou_metric: 1.0000 - val_loss: 0.0714 - val_accuracy: 0.9867 - val_precision_3: 0.9953 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9859 - val_dice_coeff: 0.8810 - val_mean_absolute_error: 0.1587 - val_my_haud_dist: 3.6053 - val_my_iou_metric: 0.6667
# Epoch 46/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1474 - accuracy: 0.9823 - precision_3: 0.9986 - mean_io_u_3: 0.1466 - recall_3: 0.9764 - dice_coeff: 0.7544 - mean_absolute_error: 0.2980 - my_haud_dist: 5.6348 - my_iou_metric: 1.0000 - val_loss: 0.0755 - val_accuracy: 0.9869 - val_precision_3: 0.9956 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9860 - val_dice_coeff: 0.8742 - val_mean_absolute_error: 0.1670 - val_my_haud_dist: 3.6489 - val_my_iou_metric: 0.7500
# Epoch 47/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1473 - accuracy: 0.9828 - precision_3: 0.9986 - mean_io_u_3: 0.1466 - recall_3: 0.9770 - dice_coeff: 0.7545 - mean_absolute_error: 0.2979 - my_haud_dist: 5.6161 - my_iou_metric: 0.7500 - val_loss: 0.0799 - val_accuracy: 0.9872 - val_precision_3: 0.9959 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9861 - val_dice_coeff: 0.8669 - val_mean_absolute_error: 0.1759 - val_my_haud_dist: 3.6954 - val_my_iou_metric: 1.0000
# Epoch 48/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1473 - accuracy: 0.9830 - precision_3: 0.9986 - mean_io_u_3: 0.1466 - recall_3: 0.9773 - dice_coeff: 0.7545 - mean_absolute_error: 0.2977 - my_haud_dist: 5.5921 - my_iou_metric: 1.0000 - val_loss: 0.0840 - val_accuracy: 0.9874 - val_precision_3: 0.9963 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9859 - val_dice_coeff: 0.8599 - val_mean_absolute_error: 0.1843 - val_my_haud_dist: 3.7421 - val_my_iou_metric: 1.0000
# Epoch 49/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1472 - accuracy: 0.9830 - precision_3: 0.9986 - mean_io_u_3: 0.1466 - recall_3: 0.9772 - dice_coeff: 0.7546 - mean_absolute_error: 0.2976 - my_haud_dist: 5.6028 - my_iou_metric: 1.0000 - val_loss: 0.0878 - val_accuracy: 0.9874 - val_precision_3: 0.9967 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9856 - val_dice_coeff: 0.8537 - val_mean_absolute_error: 0.1917 - val_my_haud_dist: 3.7834 - val_my_iou_metric: 1.0000
# Epoch 50/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1472 - accuracy: 0.9829 - precision_3: 0.9987 - mean_io_u_3: 0.1466 - recall_3: 0.9771 - dice_coeff: 0.7547 - mean_absolute_error: 0.2975 - my_haud_dist: 5.6019 - my_iou_metric: 1.0000 - val_loss: 0.0912 - val_accuracy: 0.9874 - val_precision_3: 0.9969 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9854 - val_dice_coeff: 0.8480 - val_mean_absolute_error: 0.1985 - val_my_haud_dist: 3.8213 - val_my_iou_metric: 1.0000
# Epoch 51/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1471 - accuracy: 0.9829 - precision_3: 0.9988 - mean_io_u_3: 0.1466 - recall_3: 0.9771 - dice_coeff: 0.7548 - mean_absolute_error: 0.2973 - my_haud_dist: 5.5952 - my_iou_metric: 1.0000 - val_loss: 0.0946 - val_accuracy: 0.9874 - val_precision_3: 0.9972 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9851 - val_dice_coeff: 0.8424 - val_mean_absolute_error: 0.2051 - val_my_haud_dist: 3.8990 - val_my_iou_metric: 1.0000
# Epoch 52/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1471 - accuracy: 0.9830 - precision_3: 0.9989 - mean_io_u_3: 0.1466 - recall_3: 0.9771 - dice_coeff: 0.7549 - mean_absolute_error: 0.2972 - my_haud_dist: 5.5933 - my_iou_metric: 0.7500 - val_loss: 0.0982 - val_accuracy: 0.9874 - val_precision_3: 0.9974 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9848 - val_dice_coeff: 0.8363 - val_mean_absolute_error: 0.2122 - val_my_haud_dist: 3.9734 - val_my_iou_metric: 1.0000
# Epoch 53/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1470 - accuracy: 0.9831 - precision_3: 0.9989 - mean_io_u_3: 0.1466 - recall_3: 0.9772 - dice_coeff: 0.7550 - mean_absolute_error: 0.2970 - my_haud_dist: 5.6022 - my_iou_metric: 0.7500 - val_loss: 0.1022 - val_accuracy: 0.9874 - val_precision_3: 0.9976 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9847 - val_dice_coeff: 0.8297 - val_mean_absolute_error: 0.2199 - val_my_haud_dist: 4.0547 - val_my_iou_metric: 1.0000
# Epoch 54/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1470 - accuracy: 0.9833 - precision_3: 0.9990 - mean_io_u_3: 0.1466 - recall_3: 0.9773 - dice_coeff: 0.7550 - mean_absolute_error: 0.2969 - my_haud_dist: 5.6177 - my_iou_metric: 0.7500 - val_loss: 0.1065 - val_accuracy: 0.9873 - val_precision_3: 0.9977 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9844 - val_dice_coeff: 0.8225 - val_mean_absolute_error: 0.2281 - val_my_haud_dist: 4.1772 - val_my_iou_metric: 1.0000
# Epoch 55/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1469 - accuracy: 0.9836 - precision_3: 0.9990 - mean_io_u_3: 0.1466 - recall_3: 0.9778 - dice_coeff: 0.7551 - mean_absolute_error: 0.2968 - my_haud_dist: 5.6284 - my_iou_metric: 1.0000 - val_loss: 0.1111 - val_accuracy: 0.9874 - val_precision_3: 0.9979 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9843 - val_dice_coeff: 0.8149 - val_mean_absolute_error: 0.2369 - val_my_haud_dist: 4.3274 - val_my_iou_metric: 1.0000
# Epoch 56/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1469 - accuracy: 0.9839 - precision_3: 0.9991 - mean_io_u_3: 0.1466 - recall_3: 0.9781 - dice_coeff: 0.7552 - mean_absolute_error: 0.2967 - my_haud_dist: 5.6239 - my_iou_metric: 1.0000 - val_loss: 0.1160 - val_accuracy: 0.9874 - val_precision_3: 0.9981 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9842 - val_dice_coeff: 0.8066 - val_mean_absolute_error: 0.2463 - val_my_haud_dist: 4.4813 - val_my_iou_metric: 1.0000
# Epoch 57/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1468 - accuracy: 0.9842 - precision_3: 0.9992 - mean_io_u_3: 0.1466 - recall_3: 0.9785 - dice_coeff: 0.7553 - mean_absolute_error: 0.2965 - my_haud_dist: 5.6032 - my_iou_metric: 1.0000 - val_loss: 0.1211 - val_accuracy: 0.9875 - val_precision_3: 0.9983 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9841 - val_dice_coeff: 0.7981 - val_mean_absolute_error: 0.2558 - val_my_haud_dist: 4.6478 - val_my_iou_metric: 1.0000
# Epoch 58/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1468 - accuracy: 0.9846 - precision_3: 0.9992 - mean_io_u_3: 0.1466 - recall_3: 0.9789 - dice_coeff: 0.7553 - mean_absolute_error: 0.2964 - my_haud_dist: 5.5810 - my_iou_metric: 1.0000 - val_loss: 0.1259 - val_accuracy: 0.9874 - val_precision_3: 0.9984 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9839 - val_dice_coeff: 0.7901 - val_mean_absolute_error: 0.2648 - val_my_haud_dist: 4.8025 - val_my_iou_metric: 1.0000
# Epoch 59/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1468 - accuracy: 0.9849 - precision_3: 0.9993 - mean_io_u_3: 0.1466 - recall_3: 0.9793 - dice_coeff: 0.7554 - mean_absolute_error: 0.2963 - my_haud_dist: 5.5838 - my_iou_metric: 1.0000 - val_loss: 0.1303 - val_accuracy: 0.9873 - val_precision_3: 0.9985 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9837 - val_dice_coeff: 0.7828 - val_mean_absolute_error: 0.2728 - val_my_haud_dist: 4.9412 - val_my_iou_metric: 1.0000
# Epoch 60/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1467 - accuracy: 0.9852 - precision_3: 0.9993 - mean_io_u_3: 0.1466 - recall_3: 0.9797 - dice_coeff: 0.7555 - mean_absolute_error: 0.2962 - my_haud_dist: 5.5962 - my_iou_metric: 1.0000 - val_loss: 0.1346 - val_accuracy: 0.9872 - val_precision_3: 0.9986 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9834 - val_dice_coeff: 0.7757 - val_mean_absolute_error: 0.2805 - val_my_haud_dist: 5.0788 - val_my_iou_metric: 1.0000
# Epoch 61/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1467 - accuracy: 0.9854 - precision_3: 0.9994 - mean_io_u_3: 0.1466 - recall_3: 0.9799 - dice_coeff: 0.7555 - mean_absolute_error: 0.2961 - my_haud_dist: 5.5958 - my_iou_metric: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9872 - val_precision_3: 0.9987 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9832 - val_dice_coeff: 0.7682 - val_mean_absolute_error: 0.2887 - val_my_haud_dist: 5.2040 - val_my_iou_metric: 1.0000
# Epoch 62/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1466 - accuracy: 0.9855 - precision_3: 0.9994 - mean_io_u_3: 0.1466 - recall_3: 0.9800 - dice_coeff: 0.7556 - mean_absolute_error: 0.2959 - my_haud_dist: 5.5727 - my_iou_metric: 1.0000 - val_loss: 0.1435 - val_accuracy: 0.9868 - val_precision_3: 0.9989 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9826 - val_dice_coeff: 0.7608 - val_mean_absolute_error: 0.2966 - val_my_haud_dist: 5.3348 - val_my_iou_metric: 1.0000
# Epoch 63/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1466 - accuracy: 0.9858 - precision_3: 0.9995 - mean_io_u_3: 0.1466 - recall_3: 0.9803 - dice_coeff: 0.7557 - mean_absolute_error: 0.2958 - my_haud_dist: 5.5668 - my_iou_metric: 1.0000 - val_loss: 0.1475 - val_accuracy: 0.9866 - val_precision_3: 0.9990 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9822 - val_dice_coeff: 0.7542 - val_mean_absolute_error: 0.3037 - val_my_haud_dist: 5.4773 - val_my_iou_metric: 1.0000
# Epoch 64/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1465 - accuracy: 0.9858 - precision_3: 0.9996 - mean_io_u_3: 0.1466 - recall_3: 0.9803 - dice_coeff: 0.7558 - mean_absolute_error: 0.2957 - my_haud_dist: 5.5648 - my_iou_metric: 1.0000 - val_loss: 0.1513 - val_accuracy: 0.9864 - val_precision_3: 0.9990 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9817 - val_dice_coeff: 0.7478 - val_mean_absolute_error: 0.3104 - val_my_haud_dist: 5.6035 - val_my_iou_metric: 1.0000
# Epoch 65/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1465 - accuracy: 0.9859 - precision_3: 0.9996 - mean_io_u_3: 0.1466 - recall_3: 0.9804 - dice_coeff: 0.7558 - mean_absolute_error: 0.2956 - my_haud_dist: 5.5633 - my_iou_metric: 1.0000 - val_loss: 0.1553 - val_accuracy: 0.9862 - val_precision_3: 0.9991 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9814 - val_dice_coeff: 0.7412 - val_mean_absolute_error: 0.3174 - val_my_haud_dist: 5.7207 - val_my_iou_metric: 1.0000
# Epoch 66/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1465 - accuracy: 0.9860 - precision_3: 0.9996 - mean_io_u_3: 0.1466 - recall_3: 0.9806 - dice_coeff: 0.7559 - mean_absolute_error: 0.2954 - my_haud_dist: 5.5712 - my_iou_metric: 1.0000 - val_loss: 0.1590 - val_accuracy: 0.9860 - val_precision_3: 0.9992 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9811 - val_dice_coeff: 0.7350 - val_mean_absolute_error: 0.3239 - val_my_haud_dist: 5.8391 - val_my_iou_metric: 1.0000
# Epoch 67/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1464 - accuracy: 0.9862 - precision_3: 0.9996 - mean_io_u_3: 0.1466 - recall_3: 0.9808 - dice_coeff: 0.7560 - mean_absolute_error: 0.2953 - my_haud_dist: 5.5743 - my_iou_metric: 1.0000 - val_loss: 0.1624 - val_accuracy: 0.9859 - val_precision_3: 0.9993 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9808 - val_dice_coeff: 0.7294 - val_mean_absolute_error: 0.3298 - val_my_haud_dist: 5.9611 - val_my_iou_metric: 1.0000
# Epoch 68/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1464 - accuracy: 0.9865 - precision_3: 0.9997 - mean_io_u_3: 0.1466 - recall_3: 0.9812 - dice_coeff: 0.7560 - mean_absolute_error: 0.2952 - my_haud_dist: 5.5831 - my_iou_metric: 1.0000 - val_loss: 0.1660 - val_accuracy: 0.9857 - val_precision_3: 0.9993 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9806 - val_dice_coeff: 0.7234 - val_mean_absolute_error: 0.3360 - val_my_haud_dist: 6.0598 - val_my_iou_metric: 1.0000
# Epoch 69/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1463 - accuracy: 0.9867 - precision_3: 0.9996 - mean_io_u_3: 0.1466 - recall_3: 0.9816 - dice_coeff: 0.7561 - mean_absolute_error: 0.2951 - my_haud_dist: 5.5759 - my_iou_metric: 1.0000 - val_loss: 0.1697 - val_accuracy: 0.9856 - val_precision_3: 0.9994 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9804 - val_dice_coeff: 0.7172 - val_mean_absolute_error: 0.3424 - val_my_haud_dist: 6.1630 - val_my_iou_metric: 1.0000
# Epoch 70/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1463 - accuracy: 0.9871 - precision_3: 0.9997 - mean_io_u_3: 0.1466 - recall_3: 0.9821 - dice_coeff: 0.7562 - mean_absolute_error: 0.2950 - my_haud_dist: 5.5710 - my_iou_metric: 1.0000 - val_loss: 0.1732 - val_accuracy: 0.9854 - val_precision_3: 0.9994 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9801 - val_dice_coeff: 0.7114 - val_mean_absolute_error: 0.3484 - val_my_haud_dist: 6.2777 - val_my_iou_metric: 1.0000
# Epoch 71/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1463 - accuracy: 0.9874 - precision_3: 0.9997 - mean_io_u_3: 0.1466 - recall_3: 0.9825 - dice_coeff: 0.7562 - mean_absolute_error: 0.2949 - my_haud_dist: 5.5609 - my_iou_metric: 1.0000 - val_loss: 0.1768 - val_accuracy: 0.9852 - val_precision_3: 0.9994 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9798 - val_dice_coeff: 0.7054 - val_mean_absolute_error: 0.3545 - val_my_haud_dist: 6.3838 - val_my_iou_metric: 1.0000
# Epoch 72/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1462 - accuracy: 0.9877 - precision_3: 0.9996 - mean_io_u_3: 0.1466 - recall_3: 0.9830 - dice_coeff: 0.7563 - mean_absolute_error: 0.2948 - my_haud_dist: 5.5598 - my_iou_metric: 1.0000 - val_loss: 0.1801 - val_accuracy: 0.9850 - val_precision_3: 0.9995 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9794 - val_dice_coeff: 0.6999 - val_mean_absolute_error: 0.3601 - val_my_haud_dist: 6.4665 - val_my_iou_metric: 1.0000
# Epoch 73/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1462 - accuracy: 0.9880 - precision_3: 0.9996 - mean_io_u_3: 0.1466 - recall_3: 0.9833 - dice_coeff: 0.7564 - mean_absolute_error: 0.2947 - my_haud_dist: 5.5474 - my_iou_metric: 1.0000 - val_loss: 0.1828 - val_accuracy: 0.9847 - val_precision_3: 0.9995 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9789 - val_dice_coeff: 0.6953 - val_mean_absolute_error: 0.3647 - val_my_haud_dist: 6.5609 - val_my_iou_metric: 1.0000
# Epoch 74/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1462 - accuracy: 0.9881 - precision_3: 0.9996 - mean_io_u_3: 0.1466 - recall_3: 0.9835 - dice_coeff: 0.7564 - mean_absolute_error: 0.2946 - my_haud_dist: 5.5493 - my_iou_metric: 1.0000 - val_loss: 0.1856 - val_accuracy: 0.9845 - val_precision_3: 0.9996 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9786 - val_dice_coeff: 0.6906 - val_mean_absolute_error: 0.3693 - val_my_haud_dist: 6.6371 - val_my_iou_metric: 1.0000
# Epoch 75/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1461 - accuracy: 0.9883 - precision_3: 0.9997 - mean_io_u_3: 0.1466 - recall_3: 0.9838 - dice_coeff: 0.7565 - mean_absolute_error: 0.2945 - my_haud_dist: 5.5477 - my_iou_metric: 1.0000 - val_loss: 0.1883 - val_accuracy: 0.9844 - val_precision_3: 0.9996 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9784 - val_dice_coeff: 0.6862 - val_mean_absolute_error: 0.3737 - val_my_haud_dist: 6.7112 - val_my_iou_metric: 1.0000
# Epoch 76/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1461 - accuracy: 0.9885 - precision_3: 0.9997 - mean_io_u_3: 0.1466 - recall_3: 0.9840 - dice_coeff: 0.7565 - mean_absolute_error: 0.2944 - my_haud_dist: 5.5405 - my_iou_metric: 1.0000 - val_loss: 0.1903 - val_accuracy: 0.9841 - val_precision_3: 0.9996 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9780 - val_dice_coeff: 0.6829 - val_mean_absolute_error: 0.3770 - val_my_haud_dist: 6.7795 - val_my_iou_metric: 1.0000
# Epoch 77/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1461 - accuracy: 0.9886 - precision_3: 0.9997 - mean_io_u_3: 0.1466 - recall_3: 0.9841 - dice_coeff: 0.7566 - mean_absolute_error: 0.2943 - my_haud_dist: 5.5483 - my_iou_metric: 1.0000 - val_loss: 0.1922 - val_accuracy: 0.9840 - val_precision_3: 0.9997 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9778 - val_dice_coeff: 0.6797 - val_mean_absolute_error: 0.3802 - val_my_haud_dist: 6.8332 - val_my_iou_metric: 1.0000
# Epoch 78/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1460 - accuracy: 0.9888 - precision_3: 0.9997 - mean_io_u_3: 0.1466 - recall_3: 0.9844 - dice_coeff: 0.7566 - mean_absolute_error: 0.2942 - my_haud_dist: 5.5437 - my_iou_metric: 1.0000 - val_loss: 0.1939 - val_accuracy: 0.9839 - val_precision_3: 0.9997 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9776 - val_dice_coeff: 0.6769 - val_mean_absolute_error: 0.3829 - val_my_haud_dist: 6.8787 - val_my_iou_metric: 1.0000
# Epoch 79/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1460 - accuracy: 0.9889 - precision_3: 0.9997 - mean_io_u_3: 0.1466 - recall_3: 0.9845 - dice_coeff: 0.7567 - mean_absolute_error: 0.2941 - my_haud_dist: 5.5433 - my_iou_metric: 1.0000 - val_loss: 0.1951 - val_accuracy: 0.9836 - val_precision_3: 0.9997 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9772 - val_dice_coeff: 0.6749 - val_mean_absolute_error: 0.3849 - val_my_haud_dist: 6.9295 - val_my_iou_metric: 1.0000
# Epoch 80/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1460 - accuracy: 0.9889 - precision_3: 0.9997 - mean_io_u_3: 0.1466 - recall_3: 0.9846 - dice_coeff: 0.7567 - mean_absolute_error: 0.2940 - my_haud_dist: 5.5501 - my_iou_metric: 1.0000 - val_loss: 0.1965 - val_accuracy: 0.9834 - val_precision_3: 0.9997 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9769 - val_dice_coeff: 0.6725 - val_mean_absolute_error: 0.3871 - val_my_haud_dist: 6.9619 - val_my_iou_metric: 1.0000
# Epoch 81/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1460 - accuracy: 0.9889 - precision_3: 0.9997 - mean_io_u_3: 0.1466 - recall_3: 0.9846 - dice_coeff: 0.7567 - mean_absolute_error: 0.2939 - my_haud_dist: 5.5451 - my_iou_metric: 1.0000 - val_loss: 0.1979 - val_accuracy: 0.9831 - val_precision_3: 0.9997 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9765 - val_dice_coeff: 0.6702 - val_mean_absolute_error: 0.3893 - val_my_haud_dist: 7.0012 - val_my_iou_metric: 1.0000
# Epoch 82/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1459 - accuracy: 0.9889 - precision_3: 0.9997 - mean_io_u_3: 0.1466 - recall_3: 0.9846 - dice_coeff: 0.7568 - mean_absolute_error: 0.2939 - my_haud_dist: 5.5469 - my_iou_metric: 1.0000 - val_loss: 0.1991 - val_accuracy: 0.9828 - val_precision_3: 0.9997 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9760 - val_dice_coeff: 0.6682 - val_mean_absolute_error: 0.3912 - val_my_haud_dist: 7.0494 - val_my_iou_metric: 1.0000
# Epoch 83/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1459 - accuracy: 0.9888 - precision_3: 0.9997 - mean_io_u_3: 0.1466 - recall_3: 0.9845 - dice_coeff: 0.7568 - mean_absolute_error: 0.2938 - my_haud_dist: 5.5527 - my_iou_metric: 1.0000 - val_loss: 0.2002 - val_accuracy: 0.9825 - val_precision_3: 0.9998 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9756 - val_dice_coeff: 0.6663 - val_mean_absolute_error: 0.3930 - val_my_haud_dist: 7.0712 - val_my_iou_metric: 1.0000
# Epoch 84/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1459 - accuracy: 0.9888 - precision_3: 0.9997 - mean_io_u_3: 0.1466 - recall_3: 0.9844 - dice_coeff: 0.7568 - mean_absolute_error: 0.2937 - my_haud_dist: 5.5413 - my_iou_metric: 1.0000 - val_loss: 0.2011 - val_accuracy: 0.9823 - val_precision_3: 0.9998 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9753 - val_dice_coeff: 0.6648 - val_mean_absolute_error: 0.3944 - val_my_haud_dist: 7.1043 - val_my_iou_metric: 1.0000
# Epoch 85/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1459 - accuracy: 0.9888 - precision_3: 0.9998 - mean_io_u_3: 0.1466 - recall_3: 0.9844 - dice_coeff: 0.7569 - mean_absolute_error: 0.2936 - my_haud_dist: 5.5508 - my_iou_metric: 1.0000 - val_loss: 0.2019 - val_accuracy: 0.9820 - val_precision_3: 0.9998 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9748 - val_dice_coeff: 0.6635 - val_mean_absolute_error: 0.3957 - val_my_haud_dist: 7.1276 - val_my_iou_metric: 1.0000
# Epoch 86/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1459 - accuracy: 0.9887 - precision_3: 0.9998 - mean_io_u_3: 0.1466 - recall_3: 0.9843 - dice_coeff: 0.7569 - mean_absolute_error: 0.2936 - my_haud_dist: 5.5535 - my_iou_metric: 1.0000 - val_loss: 0.2028 - val_accuracy: 0.9817 - val_precision_3: 0.9998 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9745 - val_dice_coeff: 0.6620 - val_mean_absolute_error: 0.3971 - val_my_haud_dist: 7.1466 - val_my_iou_metric: 1.0000
# Epoch 87/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1458 - accuracy: 0.9888 - precision_3: 0.9998 - mean_io_u_3: 0.1466 - recall_3: 0.9844 - dice_coeff: 0.7569 - mean_absolute_error: 0.2935 - my_haud_dist: 5.5442 - my_iou_metric: 1.0000 - val_loss: 0.2036 - val_accuracy: 0.9816 - val_precision_3: 0.9998 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9743 - val_dice_coeff: 0.6607 - val_mean_absolute_error: 0.3983 - val_my_haud_dist: 7.1750 - val_my_iou_metric: 1.0000
# Epoch 88/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1458 - accuracy: 0.9888 - precision_3: 0.9998 - mean_io_u_3: 0.1466 - recall_3: 0.9843 - dice_coeff: 0.7570 - mean_absolute_error: 0.2934 - my_haud_dist: 5.5545 - my_iou_metric: 1.0000 - val_loss: 0.2044 - val_accuracy: 0.9814 - val_precision_3: 0.9998 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9740 - val_dice_coeff: 0.6593 - val_mean_absolute_error: 0.3996 - val_my_haud_dist: 7.1974 - val_my_iou_metric: 1.0000
# Epoch 89/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1458 - accuracy: 0.9889 - precision_3: 0.9998 - mean_io_u_3: 0.1466 - recall_3: 0.9844 - dice_coeff: 0.7570 - mean_absolute_error: 0.2934 - my_haud_dist: 5.5493 - my_iou_metric: 1.0000 - val_loss: 0.2051 - val_accuracy: 0.9810 - val_precision_3: 0.9998 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9735 - val_dice_coeff: 0.6582 - val_mean_absolute_error: 0.4006 - val_my_haud_dist: 7.2214 - val_my_iou_metric: 1.0000
# Epoch 90/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1458 - accuracy: 0.9888 - precision_3: 0.9998 - mean_io_u_3: 0.1466 - recall_3: 0.9843 - dice_coeff: 0.7570 - mean_absolute_error: 0.2933 - my_haud_dist: 5.5555 - my_iou_metric: 1.0000 - val_loss: 0.2057 - val_accuracy: 0.9808 - val_precision_3: 0.9998 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9732 - val_dice_coeff: 0.6572 - val_mean_absolute_error: 0.4015 - val_my_haud_dist: 7.2381 - val_my_iou_metric: 0.7500
# Epoch 91/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1458 - accuracy: 0.9888 - precision_3: 0.9998 - mean_io_u_3: 0.1466 - recall_3: 0.9843 - dice_coeff: 0.7571 - mean_absolute_error: 0.2932 - my_haud_dist: 5.5537 - my_iou_metric: 1.0000 - val_loss: 0.2063 - val_accuracy: 0.9806 - val_precision_3: 0.9998 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9729 - val_dice_coeff: 0.6562 - val_mean_absolute_error: 0.4023 - val_my_haud_dist: 7.2520 - val_my_iou_metric: 0.7500
# Epoch 92/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1458 - accuracy: 0.9888 - precision_3: 0.9998 - mean_io_u_3: 0.1466 - recall_3: 0.9844 - dice_coeff: 0.7571 - mean_absolute_error: 0.2931 - my_haud_dist: 5.5472 - my_iou_metric: 1.0000 - val_loss: 0.2068 - val_accuracy: 0.9804 - val_precision_3: 0.9998 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9726 - val_dice_coeff: 0.6553 - val_mean_absolute_error: 0.4032 - val_my_haud_dist: 7.2771 - val_my_iou_metric: 0.7500
# Epoch 93/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1457 - accuracy: 0.9889 - precision_3: 0.9998 - mean_io_u_3: 0.1466 - recall_3: 0.9844 - dice_coeff: 0.7571 - mean_absolute_error: 0.2931 - my_haud_dist: 5.5563 - my_iou_metric: 1.0000 - val_loss: 0.2074 - val_accuracy: 0.9802 - val_precision_3: 0.9998 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9723 - val_dice_coeff: 0.6544 - val_mean_absolute_error: 0.4040 - val_my_haud_dist: 7.2895 - val_my_iou_metric: 0.7500
# Epoch 94/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1457 - accuracy: 0.9889 - precision_3: 0.9998 - mean_io_u_3: 0.1466 - recall_3: 0.9845 - dice_coeff: 0.7571 - mean_absolute_error: 0.2930 - my_haud_dist: 5.5515 - my_iou_metric: 1.0000 - val_loss: 0.2079 - val_accuracy: 0.9800 - val_precision_3: 0.9998 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.9721 - val_dice_coeff: 0.6535 - val_mean_absolute_error: 0.4048 - val_my_haud_dist: 7.3123 - val_my_iou_metric: 0.7500
# Epoch 95/200
# ...
# Epoch 169/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1446 - accuracy: 0.9930 - precision_3: 1.0000 - mean_io_u_3: 0.1466 - recall_3: 0.9902 - dice_coeff: 0.7589 - mean_absolute_error: 0.2886 - my_haud_dist: 5.6374 - my_iou_metric: 1.0000 - val_loss: 0.2339 - val_accuracy: 0.3087 - val_precision_3: 0.9996 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.0274 - val_dice_coeff: 0.6101 - val_mean_absolute_error: 0.4409 - val_my_haud_dist: 8.1093 - val_my_iou_metric: 0.0000e+00
# Epoch 170/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1446 - accuracy: 0.9932 - precision_3: 1.0000 - mean_io_u_3: 0.1466 - recall_3: 0.9904 - dice_coeff: 0.7589 - mean_absolute_error: 0.2885 - my_haud_dist: 5.6393 - my_iou_metric: 1.0000 - val_loss: 0.2349 - val_accuracy: 0.3057 - val_precision_3: 0.9995 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.0231 - val_dice_coeff: 0.6086 - val_mean_absolute_error: 0.4422 - val_my_haud_dist: 8.1280 - val_my_iou_metric: 0.0000e+00
# Epoch 171/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.1446 - accuracy: 0.9933 - precision_3: 1.0000 - mean_io_u_3: 0.1466 - recall_3: 0.9905 - dice_coeff: 0.7589 - mean_absolute_error: 0.2885 - my_haud_dist: 5.6409 - my_iou_metric: 1.0000 - val_loss: 0.2335 - val_accuracy: 0.3318 - val_precision_3: 0.9998 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.0598 - val_dice_coeff: 0.6109 - val_mean_absolute_error: 0.4400 - val_my_haud_dist: 8.0832 - val_my_iou_metric: 0.0000e+00
# Epoch 172/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1448 - accuracy: 0.9932 - precision_3: 1.0000 - mean_io_u_3: 0.1466 - recall_3: 0.9904 - dice_coeff: 0.7587 - mean_absolute_error: 0.2887 - my_haud_dist: 5.7548 - my_iou_metric: 1.0000 - val_loss: 0.2347 - val_accuracy: 0.3213 - val_precision_3: 0.9998 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.0451 - val_dice_coeff: 0.6088 - val_mean_absolute_error: 0.4419 - val_my_haud_dist: 8.1075 - val_my_iou_metric: 0.0000e+00
# Epoch 173/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1448 - accuracy: 0.9931 - precision_3: 1.0000 - mean_io_u_3: 0.1466 - recall_3: 0.9903 - dice_coeff: 0.7586 - mean_absolute_error: 0.2888 - my_haud_dist: 5.7084 - my_iou_metric: 1.0000 - val_loss: 0.2296 - val_accuracy: 0.3928 - val_precision_3: 0.9998 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.1457 - val_dice_coeff: 0.6174 - val_mean_absolute_error: 0.4340 - val_my_haud_dist: 7.9808 - val_my_iou_metric: 0.0000e+00
# Epoch 174/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1447 - accuracy: 0.9929 - precision_3: 1.0000 - mean_io_u_3: 0.1466 - recall_3: 0.9900 - dice_coeff: 0.7589 - mean_absolute_error: 0.2885 - my_haud_dist: 5.6812 - my_iou_metric: 1.0000 - val_loss: 0.2280 - val_accuracy: 0.5037 - val_precision_3: 0.9998 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.3017 - val_dice_coeff: 0.6200 - val_mean_absolute_error: 0.4314 - val_my_haud_dist: 7.9298 - val_my_iou_metric: 0.0000e+00
# Epoch 175/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1447 - accuracy: 0.9925 - precision_3: 1.0000 - mean_io_u_3: 0.1466 - recall_3: 0.9893 - dice_coeff: 0.7588 - mean_absolute_error: 0.2885 - my_haud_dist: 5.6839 - my_iou_metric: 1.0000 - val_loss: 0.2300 - val_accuracy: 0.3410 - val_precision_3: 0.9993 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.0728 - val_dice_coeff: 0.6166 - val_mean_absolute_error: 0.4344 - val_my_haud_dist: 7.9915 - val_my_iou_metric: 0.0000e+00
# Epoch 176/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1446 - accuracy: 0.9927 - precision_3: 1.0000 - mean_io_u_3: 0.1466 - recall_3: 0.9896 - dice_coeff: 0.7590 - mean_absolute_error: 0.2883 - my_haud_dist: 5.6700 - my_iou_metric: 1.0000 - val_loss: 0.2327 - val_accuracy: 0.3142 - val_precision_3: 0.9988 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.0352 - val_dice_coeff: 0.6121 - val_mean_absolute_error: 0.4386 - val_my_haud_dist: 8.0638 - val_my_iou_metric: 0.0000e+00
# Epoch 177/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1446 - accuracy: 0.9934 - precision_3: 1.0000 - mean_io_u_3: 0.1466 - recall_3: 0.9907 - dice_coeff: 0.7590 - mean_absolute_error: 0.2883 - my_haud_dist: 5.6844 - my_iou_metric: 1.0000 - val_loss: 0.2330 - val_accuracy: 0.3134 - val_precision_3: 0.9991 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.0340 - val_dice_coeff: 0.6117 - val_mean_absolute_error: 0.4389 - val_my_haud_dist: 8.0778 - val_my_iou_metric: 0.0000e+00
# Epoch 178/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1446 - accuracy: 0.9934 - precision_3: 1.0000 - mean_io_u_3: 0.1466 - recall_3: 0.9907 - dice_coeff: 0.7590 - mean_absolute_error: 0.2883 - my_haud_dist: 5.6762 - my_iou_metric: 1.0000 - val_loss: 0.2322 - val_accuracy: 0.3172 - val_precision_3: 0.9986 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.0394 - val_dice_coeff: 0.6130 - val_mean_absolute_error: 0.4375 - val_my_haud_dist: 8.0679 - val_my_iou_metric: 0.0000e+00
# Epoch 179/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1446 - accuracy: 0.9933 - precision_3: 1.0000 - mean_io_u_3: 0.1466 - recall_3: 0.9905 - dice_coeff: 0.7590 - mean_absolute_error: 0.2882 - my_haud_dist: 5.6604 - my_iou_metric: 1.0000 - val_loss: 0.2313 - val_accuracy: 0.3248 - val_precision_3: 0.9987 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.0501 - val_dice_coeff: 0.6146 - val_mean_absolute_error: 0.4361 - val_my_haud_dist: 8.0350 - val_my_iou_metric: 0.0000e+00
# Epoch 180/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1446 - accuracy: 0.9935 - precision_3: 1.0000 - mean_io_u_3: 0.1466 - recall_3: 0.9908 - dice_coeff: 0.7590 - mean_absolute_error: 0.2882 - my_haud_dist: 5.7304 - my_iou_metric: 1.0000 - val_loss: 0.2309 - val_accuracy: 0.3240 - val_precision_3: 0.9987 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.0489 - val_dice_coeff: 0.6151 - val_mean_absolute_error: 0.4355 - val_my_haud_dist: 8.0307 - val_my_iou_metric: 0.0000e+00
# Epoch 181/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1446 - accuracy: 0.9936 - precision_3: 1.0000 - mean_io_u_3: 0.1466 - recall_3: 0.9909 - dice_coeff: 0.7591 - mean_absolute_error: 0.2881 - my_haud_dist: 5.6812 - my_iou_metric: 0.7500 - val_loss: 0.2322 - val_accuracy: 0.3151 - val_precision_3: 0.9979 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.0364 - val_dice_coeff: 0.6130 - val_mean_absolute_error: 0.4373 - val_my_haud_dist: 8.0517 - val_my_iou_metric: 0.0000e+00
# Epoch 182/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1445 - accuracy: 0.9933 - precision_3: 1.0000 - mean_io_u_3: 0.1466 - recall_3: 0.9906 - dice_coeff: 0.7591 - mean_absolute_error: 0.2880 - my_haud_dist: 5.6756 - my_iou_metric: 1.0000 - val_loss: 0.2330 - val_accuracy: 0.3109 - val_precision_3: 0.9979 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.0305 - val_dice_coeff: 0.6116 - val_mean_absolute_error: 0.4386 - val_my_haud_dist: 8.0943 - val_my_iou_metric: 0.0000e+00
# Epoch 183/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1445 - accuracy: 0.9935 - precision_3: 1.0000 - mean_io_u_3: 0.1466 - recall_3: 0.9908 - dice_coeff: 0.7591 - mean_absolute_error: 0.2880 - my_haud_dist: 5.6794 - my_iou_metric: 0.7500 - val_loss: 0.2325 - val_accuracy: 0.3125 - val_precision_3: 0.9987 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.0327 - val_dice_coeff: 0.6125 - val_mean_absolute_error: 0.4378 - val_my_haud_dist: 8.0796 - val_my_iou_metric: 0.0000e+00
# Epoch 184/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1445 - accuracy: 0.9937 - precision_3: 1.0000 - mean_io_u_3: 0.1466 - recall_3: 0.9911 - dice_coeff: 0.7591 - mean_absolute_error: 0.2879 - my_haud_dist: 5.6556 - my_iou_metric: 0.7500 - val_loss: 0.2328 - val_accuracy: 0.3107 - val_precision_3: 0.9986 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.0302 - val_dice_coeff: 0.6120 - val_mean_absolute_error: 0.4382 - val_my_haud_dist: 8.0908 - val_my_iou_metric: 0.0000e+00
# Epoch 185/200
# 1/1 [==============================] - 15s 15s/step - loss: 0.1445 - accuracy: 0.9935 - precision_3: 1.0000 - mean_io_u_3: 0.1466 - recall_3: 0.9908 - dice_coeff: 0.7592 - mean_absolute_error: 0.2878 - my_haud_dist: 5.6485 - my_iou_metric: 0.7500 - val_loss: 0.2336 - val_accuracy: 0.3077 - val_precision_3: 0.9983 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.0260 - val_dice_coeff: 0.6107 - val_mean_absolute_error: 0.4393 - val_my_haud_dist: 8.1100 - val_my_iou_metric: 0.0000e+00
# Epoch 186/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1445 - accuracy: 0.9937 - precision_3: 1.0000 - mean_io_u_3: 0.1466 - recall_3: 0.9911 - dice_coeff: 0.7592 - mean_absolute_error: 0.2878 - my_haud_dist: 5.6782 - my_iou_metric: 0.7500 - val_loss: 0.2342 - val_accuracy: 0.3060 - val_precision_3: 0.9986 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.0236 - val_dice_coeff: 0.6096 - val_mean_absolute_error: 0.4402 - val_my_haud_dist: 8.1390 - val_my_iou_metric: 0.0000e+00
# Epoch 187/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1445 - accuracy: 0.9942 - precision_3: 1.0000 - mean_io_u_3: 0.1466 - recall_3: 0.9918 - dice_coeff: 0.7592 - mean_absolute_error: 0.2878 - my_haud_dist: 5.6747 - my_iou_metric: 1.0000 - val_loss: 0.2354 - val_accuracy: 0.3037 - val_precision_3: 0.9984 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.0203 - val_dice_coeff: 0.6076 - val_mean_absolute_error: 0.4419 - val_my_haud_dist: 8.1636 - val_my_iou_metric: 0.0000e+00
# Epoch 188/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1445 - accuracy: 0.9941 - precision_3: 1.0000 - mean_io_u_3: 0.1466 - recall_3: 0.9916 - dice_coeff: 0.7592 - mean_absolute_error: 0.2877 - my_haud_dist: 5.6750 - my_iou_metric: 0.7500 - val_loss: 0.2356 - val_accuracy: 0.3028 - val_precision_3: 0.9983 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.0191 - val_dice_coeff: 0.6074 - val_mean_absolute_error: 0.4421 - val_my_haud_dist: 8.1714 - val_my_iou_metric: 0.0000e+00
# Epoch 189/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1444 - accuracy: 0.9941 - precision_3: 1.0000 - mean_io_u_3: 0.1466 - recall_3: 0.9916 - dice_coeff: 0.7593 - mean_absolute_error: 0.2876 - my_haud_dist: 5.6676 - my_iou_metric: 0.7500 - val_loss: 0.2351 - val_accuracy: 0.3032 - val_precision_3: 0.9984 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.0196 - val_dice_coeff: 0.6082 - val_mean_absolute_error: 0.4413 - val_my_haud_dist: 8.1602 - val_my_iou_metric: 0.0000e+00
# Epoch 190/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1444 - accuracy: 0.9943 - precision_3: 1.0000 - mean_io_u_3: 0.1466 - recall_3: 0.9920 - dice_coeff: 0.7593 - mean_absolute_error: 0.2876 - my_haud_dist: 5.6645 - my_iou_metric: 1.0000 - val_loss: 0.2355 - val_accuracy: 0.3023 - val_precision_3: 0.9982 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.0183 - val_dice_coeff: 0.6075 - val_mean_absolute_error: 0.4418 - val_my_haud_dist: 8.1719 - val_my_iou_metric: 0.0000e+00
# Epoch 191/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1444 - accuracy: 0.9941 - precision_3: 1.0000 - mean_io_u_3: 0.1466 - recall_3: 0.9916 - dice_coeff: 0.7593 - mean_absolute_error: 0.2875 - my_haud_dist: 5.6530 - my_iou_metric: 0.7500 - val_loss: 0.2359 - val_accuracy: 0.3013 - val_precision_3: 0.9981 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.0170 - val_dice_coeff: 0.6069 - val_mean_absolute_error: 0.4423 - val_my_haud_dist: 8.1794 - val_my_iou_metric: 0.0000e+00
# Epoch 192/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.1444 - accuracy: 0.9941 - precision_3: 1.0000 - mean_io_u_3: 0.1466 - recall_3: 0.9917 - dice_coeff: 0.7593 - mean_absolute_error: 0.2875 - my_haud_dist: 5.6741 - my_iou_metric: 1.0000 - val_loss: 0.2362 - val_accuracy: 0.3002 - val_precision_3: 0.9972 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.0155 - val_dice_coeff: 0.6063 - val_mean_absolute_error: 0.4429 - val_my_haud_dist: 8.1905 - val_my_iou_metric: 0.0000e+00
# Epoch 193/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1444 - accuracy: 0.9944 - precision_3: 1.0000 - mean_io_u_3: 0.1466 - recall_3: 0.9921 - dice_coeff: 0.7593 - mean_absolute_error: 0.2874 - my_haud_dist: 5.6492 - my_iou_metric: 1.0000 - val_loss: 0.2367 - val_accuracy: 0.2995 - val_precision_3: 0.9970 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.0144 - val_dice_coeff: 0.6056 - val_mean_absolute_error: 0.4435 - val_my_haud_dist: 8.1996 - val_my_iou_metric: 0.0000e+00
# Epoch 194/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1444 - accuracy: 0.9944 - precision_3: 1.0000 - mean_io_u_3: 0.1466 - recall_3: 0.9921 - dice_coeff: 0.7594 - mean_absolute_error: 0.2874 - my_haud_dist: 5.6513 - my_iou_metric: 1.0000 - val_loss: 0.2374 - val_accuracy: 0.2982 - val_precision_3: 0.9966 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.0127 - val_dice_coeff: 0.6043 - val_mean_absolute_error: 0.4445 - val_my_haud_dist: 8.2283 - val_my_iou_metric: 0.0000e+00
# Epoch 195/200
# 1/1 [==============================] - 14s 14s/step - loss: 0.1444 - accuracy: 0.9944 - precision_3: 1.0000 - mean_io_u_3: 0.1466 - recall_3: 0.9921 - dice_coeff: 0.7594 - mean_absolute_error: 0.2873 - my_haud_dist: 5.6627 - my_iou_metric: 1.0000 - val_loss: 0.2375 - val_accuracy: 0.2977 - val_precision_3: 0.9964 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.0119 - val_dice_coeff: 0.6042 - val_mean_absolute_error: 0.4447 - val_my_haud_dist: 8.2335 - val_my_iou_metric: 0.0000e+00
# Epoch 196/200
# 1/1 [==============================] - 14s 14s/step - loss: 0.1444 - accuracy: 0.9946 - precision_3: 1.0000 - mean_io_u_3: 0.1466 - recall_3: 0.9924 - dice_coeff: 0.7594 - mean_absolute_error: 0.2873 - my_haud_dist: 5.6683 - my_iou_metric: 1.0000 - val_loss: 0.2381 - val_accuracy: 0.2970 - val_precision_3: 0.9961 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.0110 - val_dice_coeff: 0.6031 - val_mean_absolute_error: 0.4455 - val_my_haud_dist: 8.2519 - val_my_iou_metric: 0.0000e+00
# Epoch 197/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1443 - accuracy: 0.9946 - precision_3: 1.0000 - mean_io_u_3: 0.1466 - recall_3: 0.9924 - dice_coeff: 0.7594 - mean_absolute_error: 0.2872 - my_haud_dist: 5.6603 - my_iou_metric: 1.0000 - val_loss: 0.2378 - val_accuracy: 0.2976 - val_precision_3: 0.9964 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.0118 - val_dice_coeff: 0.6037 - val_mean_absolute_error: 0.4449 - val_my_haud_dist: 8.2415 - val_my_iou_metric: 0.0000e+00
# Epoch 198/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1443 - accuracy: 0.9946 - precision_3: 1.0000 - mean_io_u_3: 0.1466 - recall_3: 0.9924 - dice_coeff: 0.7594 - mean_absolute_error: 0.2872 - my_haud_dist: 5.6623 - my_iou_metric: 1.0000 - val_loss: 0.2389 - val_accuracy: 0.2963 - val_precision_3: 0.9957 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.0099 - val_dice_coeff: 0.6018 - val_mean_absolute_error: 0.4466 - val_my_haud_dist: 8.2701 - val_my_iou_metric: 0.0000e+00
# Epoch 199/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1444 - accuracy: 0.9947 - precision_3: 1.0000 - mean_io_u_3: 0.1466 - recall_3: 0.9925 - dice_coeff: 0.7594 - mean_absolute_error: 0.2872 - my_haud_dist: 5.7030 - my_iou_metric: 1.0000 - val_loss: 0.2370 - val_accuracy: 0.3001 - val_precision_3: 0.9972 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.0153 - val_dice_coeff: 0.6051 - val_mean_absolute_error: 0.4436 - val_my_haud_dist: 8.2073 - val_my_iou_metric: 0.0000e+00
# Epoch 200/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1445 - accuracy: 0.9948 - precision_3: 1.0000 - mean_io_u_3: 0.1466 - recall_3: 0.9926 - dice_coeff: 0.7592 - mean_absolute_error: 0.2874 - my_haud_dist: 5.6878 - my_iou_metric: 1.0000 - val_loss: 0.2407 - val_accuracy: 0.3004 - val_precision_3: 0.9980 - val_mean_io_u_3: 0.1446 - val_recall_3: 0.0157 - val_dice_coeff: 0.5988 - val_mean_absolute_error: 0.4492 - val_my_haud_dist: 8.2979 - val_my_iou_metric: 0.0000e+00

# %%
preds_train = model.predict(X_train_20[:int(X_train_20.shape[0]*(1-val_split))], verbose=1)
preds_x = model.predict(X_train, verbose=1)
preds_val = model.predict(X_train_20[int(X_train_20.shape[0]*(1-val_split)):], verbose=1)
preds_test = model.predict(X_test, verbose=1)

gt_train = Y_train_20[:int(X_train_20.shape[0]*(1-val_split))].astype(np.float32)
gt_x = Y_train.astype(np.float32)
gt_val = Y_train_20[int(X_train.shape[0]*(1-val_split)):].astype(np.float32)
gt_test = Y_test.astype(np.float32)
# Out:
# 1/1 [==============================] - 14s 14s/step
# 1/1 [==============================] - 19s 19s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 20s 20s/step

# %%
# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.float32)
preds_x_t = (preds_x > 0.5).astype(np.float32)
preds_val_t = (preds_val > 0.5).astype(np.float32)
preds_test_t = (preds_test > 0.5).astype(np.float32)

# %%
evalResult(gt_train, preds_train_t)
# Out:
# Accuracy= 0.3004837 Precision= 1.0 Recall= 0.010180287 MeanIoU= 0.15279742 DiceCoefficient= 0.020179741084575653 HD= 15.264302376253086 MyIoU= 0.0 MAE= 0.6995163

# %%
evalResult(gt_x, preds_x_t)
# Out:
# Accuracy= 0.30005342 Precision= 0.99819595 Recall= 0.011329543 MeanIoU= 0.15286161 DiceCoefficient= 0.02240022420883179 HD= 15.03242801907883 MyIoU= 0.0 MAE= 0.6999466

# %%
evalResult(gt_test, preds_test_t)
# Out:
# Accuracy= 0.30074158 Precision= 0.9989827 Recall= 0.011648584 MeanIoU= 0.15328968 DiceCoefficient= 0.02304135588929057 HD= 14.991892952622624 MyIoU= 0.0 MAE= 0.69925845

# %%
x=0

xx = [1,0,0]
for i in range(3):
    plt.figure(figsize=(10,10))
    #ix = random.randint(0, len(preds_train))
    ix = xx[i]
    #print(ix)
    #ix = 58
    plt.subplot(3,3,x+1)
    imshow(X_train[:int(X_train.shape[0]*(1-val_split))][ix].astype('uint8'))
    #plt.title('Image')

    plt.subplot(3,3,x+2)
    imshow(np.squeeze(Y_train[:int(Y_train.shape[0]*(1-val_split))][ix]))
    #plt.title('Mask')

    plt.subplot(3,3,x+3)
    imshow(np.squeeze(preds_train_t[ix]))
    #plt.title('Predicted Mask')
    #plt.show()
    
    plt.show()
    evalResult(Y_train[:int(Y_train.shape[0]*(1-val_split))][ix], preds_train_t[ix])
    x = x+3
# Out:
# C:\Users\manda\anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:150: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)
# Accuracy= 0.29711914 Precision= 1.0 Recall= 0.009738375 MeanIoU= 0.15098262 DiceCoefficient= 0.09441885232627101 HD= 15.231546211727817 MyIoU= 0.0 MAE= 0.70288086
# Accuracy= 0.30384827 Precision= 1.0 Recall= 0.010626071 MeanIoU= 0.15461507 DiceCoefficient= 0.09697977156974957 HD= 15.297058540778355 MyIoU= 0.0 MAE= 0.69615173
# Accuracy= 0.30384827 Precision= 1.0 Recall= 0.010626071 MeanIoU= 0.15461507 DiceCoefficient= 0.09697977156974957 HD= 15.297058540778355 MyIoU= 0.0 MAE= 0.69615173

# %%
x=0
xx = [16,10,15]
for i in range(3):
    plt.figure(figsize=(10,10))
    #ix = random.randint(0, len(preds_train))
    ix = xx[i]
    #print(ix)
    #ix = 58
    plt.subplot(3,3,x+1)
    imshow(X_test[ix].astype('uint8'))
    #plt.title('Image')

    plt.subplot(3,3,x+2)
    imshow(np.squeeze(Y_test[ix]))
    #plt.title('Mask')

    plt.subplot(3,3,x+3)
    imshow(np.squeeze(preds_test_t[ix]))
    #plt.title('Predicted Mask')
    #plt.show()
    
    plt.show()
    evalResult(Y_test[ix], preds_test_t[ix])
    x = x+3
# Out:
# Accuracy= 0.3046112 Precision= 0.9983165 Recall= 0.012845229 MeanIoU= 0.15555325 DiceCoefficient= 0.10165109334047884 HD= 15.264337522473747 MyIoU= 0.0 MAE= 0.6953888
# Accuracy= 0.29751587 Precision= 1.0 Recall= 0.01121134 MeanIoU= 0.15154347 DiceCoefficient= 0.0970958077632531 HD= 15.297058540778355 MyIoU= 0.0 MAE= 0.70248413
# Accuracy= 0.29862976 Precision= 1.0 Recall= 0.011866629 MeanIoU= 0.15226933 DiceCoefficient= 0.09986816744822136 HD= 15.165750888103101 MyIoU= 0.0 MAE= 0.70137024
